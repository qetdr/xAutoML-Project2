# %% [markdown]
# # Assignment
# This project aims to use AutoML to predict clinical outcomes using imaging and clinical variables. The imaging modality of interest is positron emission tomography (PET). We provide a data dictionary sheet that has an explanation for what each variable resembles.
#
# The outcome of interest to predict is MACE with heart failure (`o_mace` column). Variables to include in the model are highlighted in <font color='gold'>yellow </font>. (This includes the bare minimum of variables, avoiding known collinearity). Variables highlighted in <font color = 'blue'>blue</font> are variables that are known to be collinear, with some of the yellow-highlighted ones.
#
# As a **second step**, if you can please build another predictive model **using BOTH the <font color = 'gold'>yellow</font> and the <font color = 'blue'>blue</font> highlighted variables**, just to assess if some of the collinear variables may be more predictive than others. (This model will have a large number of variables in the model).
#
# Variables **not to be used** for building the model (may be used at a later point) are highlighted in <font color = 'grey'>grey</font>.
#
# One thing to note is the unindexed values for `lvmass`, `EF`, and `systolic/diastolic` volumes but not the indexed ones (indexed ones end with `_ind`). This is to avoid collinearity, too, so only include the indexed ones with the rest of the variables in the model for model 2 but not model 1.
#
# Once the model is built, we need to explain the outcome based on different groups of interest (i.e, different age groups, different race/ethnicity groups ). For interpretability, we can explore different options; LIME, SHAP,..etc.

# %% [markdown]
# # Setup

# %%
# Install the packages defined in `requirements.txt`
# !pip install -r requirements.txt

# %%
# Working with data frames
import pandas as pd
import numpy as np
import sklearn.datasets

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from tpot import TPOTClassifier

from collections import Counter
from sklearn.datasets import make_classification
from imblearn.under_sampling import CondensedNearestNeighbour
from numpy import where
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score, roc_auc_score

# Misc
import pickle
import datetime
import warnings
#from google.colab.output import eval_js
#eval_js('google.colab.output.setIframeHeight("500")') # output cell size in GC
warnings.filterwarnings('ignore') # disable warnings
# Out:
# C:\Users\burno\AppData\Local\Programs\Python\Python38\lib\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %% [markdown]
# # Data Import
# Because the data are confidential, we are not allowed to include it in the repository. Hence, we import it from a local machine outside of the working directory (the present repository).
#
# Of note, we mport two sheets from the Excel workbook: the data and the legend (data dictionary) sheets. The latter is used for, e.g., excluding the <font color='grey'> grey </font> features, as well as building models without and with <font color='blue'> blue </font> features.

# %%
df_raw = pd.read_excel('df_project2.xlsx', sheet_name = 'complete_db') # read the df from outside the directory 
df_legend = pd.read_excel('df_project2.xlsx', sheet_name = 'data_dictionary') # read the data dictionary

df_legend.head()
# Out:
#    position          name_col              name   type  isnumeric  format  \
# 0         1  annon_serial_num  annon_serial_num  float          1   %9.0g
# 1         2            sd_age            sd_age   byte          1  %10.0g
# 2         3            sd_sex            sd_sex   str6          0     %9s
# 3         4   sd_race_unified   sd_race_unified  str38          0    %38s
# 4         5   sd_ethn_unified   sd_ethn_unified  str12          0    %12s
#
#   vallab              varlab         Explanation column_color  no_yes_vars
# 0    NaN  group(id pet_date)                 NaN       yellow          0.0
# 1    NaN              sd_age         patient age       yellow          0.0
# 2    NaN              sd_sex      patient gender       yellow          0.0
# 3    NaN     sd_race_unified        patient race       yellow          0.0
# 4    NaN     sd_ethn_unified  patient ethinicity         blue          0.0

# %% [markdown]
# ## Basic Data Preprocessing

# %%
# remove non-_ind columns
print(f"df_raw dimensions before removing non-'_ind' cols:{df_raw.shape} ")
# Find columns that end with '_ind'
ind_cols = df_raw.columns[df_raw.columns.str.endswith('_ind')]
# Find column names that have both 'raw' and 'index' column
colnames_non_ind = ind_cols.str.replace('_ind', '')

# Remove the non-_ind columns
remove_yellows = []
for col in colnames_non_ind:
  all_cols = df_raw.columns[df_raw.columns.str.startswith(col)]
  for col2 in all_cols:
    if '_ind' in col2:
      pass
    else:
      remove_yellows.append(col2)
      df_raw = df_raw.drop(columns = [col2])
print(f"df_raw dimensions after removing non-'_ind' cols:{df_raw.shape} ")

# Find the column names based on color
grey_cols = df_legend[df_legend['column_color'] == 'grey']['name_col']
blue_cols = df_legend[df_legend['column_color'] == 'blue']['name_col']
yellow_cols = df_legend[df_legend['column_color'] == 'yellow']['name_col']
# Remove the non-_ind cols
yellow_cols = yellow_cols[~yellow_cols.isin(remove_yellows)].reset_index(drop = True)
green_cols = df_legend[df_legend['column_color'] == 'green']['name_col']


# Find the binary No/Yes vars (to be replaced with 0/1)
yes_no_cols = df_legend[df_legend['no_yes_vars'] == 1]['name_col'].values
df_raw[yes_no_cols] = df_raw[yes_no_cols].replace(to_replace=['No', 
                                                              'Yes'], 
                                                  value=[0, 1]) # replace No-Yes to 0-1

# Binarize 'sex' variable
df_raw['sd_sex'] = df_raw['sd_sex'].replace(to_replace=['Male', 
                                                        'Female'], 
                                            value=[0, 1])

# Binarize 'pharm_stressor'
df_raw['pharm_stressor'] = df_raw['pharm_stressor'].replace(to_replace=['Adenosine', 
                                                                        'Regadenoson'], 
                                                            value=[0, 1])

# Convert 'sd_bmi_cat' and 'cac_cat' to ordered numeric variable
df_raw['sd_bmi_cat'] = df_raw['sd_bmi_cat'].replace(to_replace = ['Underweight (<18.5kg/m2)',
                                           'Normal (18.5-25kg/m2)',
                                           'Overweight (25-30kg/m2)',
                                           'Obese (≥30kg/m2)'
                                           ],
                             value = [1,2,3,4])

df_raw['cac_cat'] = df_raw['cac_cat'].replace(to_replace = ['CACS 0', 
                                        'CACS 1-99','CACS 100-399',
                                        'CACS 400-999', 'CACS ≥1000'],
                          value = [0,1,2,3,4])
# Out:
# df_raw dimensions before removing non-'_ind' cols:(4323, 109)
# df_raw dimensions after removing non-'_ind' cols:(4323, 105)

# %% [markdown]
# ## Dataset Extraction

# %%
# Extract the target
target = df_raw[green_cols]['o_mace']

# Create the yellow X features df (X1)
X1 = df_raw[yellow_cols]

# Create the yellow-blue X features df (X2)
X2 = df_raw.drop(columns = grey_cols.append(green_cols))

# Drop the ID-col (it's sequential and can be easily retrieved)
X1 = X1.drop(columns = 'annon_serial_num')
X2 = X2.drop(columns = 'annon_serial_num')

# Convert `object` vars to dummies (TPOT might not deal well with cat-vars)
X1 = pd.get_dummies(X1)
X2 = pd.get_dummies(X2)


# Print the dimensions
print(f'Initial df dimensions: {df_raw.shape}')
print(f'Yellow X df dimensions: {X1.shape}')
print(f'Yellow-blue X df dimensions: {X2.shape}')
print(f'target dimensions: {target.shape}')
# Out:
# Initial df dimensions: (4323, 105)
# Yellow X df dimensions: (4323, 61)
# Yellow-blue X df dimensions: (4323, 86)
# target dimensions: (4323,)

# %% [markdown]
# ## Remove and check missing values and other data characteristics

# %%
imputer = SimpleImputer(strategy="median")

imputer.fit(X1)
X1_no_nan = imputer.transform(X1)
X1 = pd.DataFrame(X1_no_nan, columns = X1.columns)

imputer.fit(X2)
X2_no_nan = imputer.transform(X2)
X2 = pd.DataFrame(X2_no_nan, columns = X2.columns)

# %%
print('Number of missing values:')
print()
print(f'Target y: {target.isnull().sum().sum()}')
print(f'Target X1: {X1.isnull().sum().sum()}')
print(f'Target X2: {X2.isnull().sum().sum()}')
# Out:
# Number of missing values:
#
# Target y: 0
# Target X1: 0
# Target X2: 0

# %% [markdown]
# ## Undersample with the Condensed Nearest Neighbor Rule

# %%
# define the undersampling method
undersample = CondensedNearestNeighbour(n_neighbors=1)

print('Model X1')
print(Counter(target))
# transform the datasets
X1_under, target1 = undersample.fit_resample(X1, target)
# summarize the new class distribution
print(Counter(target1))

undersample = CondensedNearestNeighbour(n_neighbors=65)

print('Model X2')
print(Counter(target))
# transform the datasets
X2_under, target2 = undersample.fit_resample(X2, target)
# summarize the new class distribution
print(Counter(target2))
# Out:
# Model X1
# Counter({0: 4017, 1: 306})
# Counter({0: 787, 1: 306})
# Model X2
# Counter({0: 4017, 1: 306})
# Counter({0: 392, 1: 306})

# %% [markdown]
# # Train-test split and save the data

# %%
# Train-test split for yellow X
X1_train, X1_val, y1_train, y1_val = train_test_split(X1_under, target1, test_size=0.2, random_state=42)

# Train-test split for yellow-blue X
X2_train, X2_val, y2_train, y2_val = train_test_split(X2_under, target2, test_size=0.3, random_state=42)

# %%
# Data to pickle (for later retrieval)
X1_train.to_pickle("./X1_train.pkl")
y1_train.to_pickle("./y1_train.pkl")
X2_train.to_pickle("./X2_train.pkl")
y2_train.to_pickle("./y2_train.pkl")
X1_val.to_pickle("./X1_val.pkl")
y1_val.to_pickle("./y1_val.pkl")
X2_val.to_pickle("./X2_val.pkl")
y2_val.to_pickle("./y2_val.pkl")
X1.to_pickle("./X1.pkl")
X2.to_pickle("./X2.pkl")
target.to_pickle("./target.pkl")

# %% [markdown]
# # TPOT
# - Maybe also see this tutorial: https://medium.com/analytics-vidhya/learn-to-use-tpot-an-automl-tool-4c52148c2bc9
# - A paper using TPOT for medical classification: https://academic.oup.com/bioinformatics/article/36/6/1772/5614811
# - More about `TPOTClassifier` class args: http://epistasislab.github.io/tpot/using/
# - TPOT Github repo: https://github.com/EpistasisLab/tpot

# %% [markdown]
# # 1st `tpot` run

# %%
def build_tpot(X_train, y_train, max_time_mins = None):

  # Initialize the TPOT framework for classification.
  tpot = TPOTClassifier(
    generations=100, # Number of iterations to run the pipeline optimization process.
    population_size=20, # Number of individuals to retain in the GP population every generation. 
    scoring = 'f1_weighted', # use the wieghted F1 score
    cv = 5,
    n_jobs = -1, # all CPUs are used.
    max_time_mins = max_time_mins,
    max_eval_time_mins = 5,
    random_state = 42,
    verbosity = 2
  )

  # Fit the framework.
  tpot.fit(X_train, y_train)

  return tpot


def run_tpot(X, y, max_time_mins, n_splits=3):

  # Limit time to be equally between all fold and
  # also the final run on the entire dataset.
  time_limit = max(1, max_time_mins // (n_splits + 1))

  # Informative runtime information.
  start_run = datetime.datetime.now()
  estimated_end = start_run + datetime.timedelta(minutes=time_limit*(n_splits + 1))
  print(f'Start TPOT:  {start_run} Time Limit per Fold: {time_limit}min')
  print(f'Estimated end: {estimated_end}\n')

  skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
  scores = []

  # Perform startified cross validation.s
  for train_index, val_index in skf.split(X, y):

    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    tpot = build_tpot(X_train, y_train, time_limit)

    # Predictions and weighted F1-score.
    y_pred = tpot.predict(X_val)
    score = f1_score(y_pred, y_val, average='weighted')
    scores.append(score)

  # Building the final TPOT model on all samples.
  tpot = build_tpot(X, y, time_limit)
  avg_score = sum(scores) / len(scores)

  print()
  print(f'Weighted F1-score: {avg_score}\n')
  print(f'End of the TPOT system execution: {datetime.datetime.now()}\n')

  return tpot

# %%
tpot_X1 = run_tpot(X1_train, y1_train, max_time_mins=20)

# Save the model
tpot_X1.export('tpot_models/tpot_X1.py')

# Save the model as pickle
with open("./tpot_model_X1.pickle", "wb") as f:
    pickle.dump({"template": tpot_X1.fitted_pipeline_, "_imputed": tpot_X1._imputed}, f)
# Out:
# Start TPOT:  2023-01-14 11:17:29.973738 Time Limit per Fold: 5min
# Estimated end: 2023-01-14 11:37:29.973738
#
#
# Generation 1 - Current best internal CV score: 0.6794290682400496
#
# Generation 2 - Current best internal CV score: 0.7083765222788534
#
# Generation 3 - Current best internal CV score: 0.7083765222788534
#
# Generation 4 - Current best internal CV score: 0.7083765222788534
#
# Generation 5 - Current best internal CV score: 0.7125338529003364
#
# Generation 6 - Current best internal CV score: 0.7125338529003364
#
# Generation 7 - Current best internal CV score: 0.7147833019373457
#
# Generation 8 - Current best internal CV score: 0.7147833019373457
#
# Generation 9 - Current best internal CV score: 0.7174141325515437
#
# Generation 10 - Current best internal CV score: 0.7186275728622252
#
# Generation 11 - Current best internal CV score: 0.7199961185855307
#
# Generation 12 - Current best internal CV score: 0.7199961185855307
#
# Generation 13 - Current best internal CV score: 0.7228686179681086
#
# Generation 14 - Current best internal CV score: 0.7250955562349766
#
# Generation 15 - Current best internal CV score: 0.7250955562349766
#
# Generation 16 - Current best internal CV score: 0.7250955562349766
#
# Generation 17 - Current best internal CV score: 0.7250955562349766
#
# Generation 18 - Current best internal CV score: 0.7325014154290111
#
# Generation 19 - Current best internal CV score: 0.7325014154290111
#
# Generation 20 - Current best internal CV score: 0.7390216750143496
#
# Generation 21 - Current best internal CV score: 0.7406269268894125
#
# Generation 22 - Current best internal CV score: 0.7406269268894125
#
# Generation 23 - Current best internal CV score: 0.7406269268894125
#
# Generation 24 - Current best internal CV score: 0.7406269268894125
#
# Generation 25 - Current best internal CV score: 0.7406269268894125
#
# Generation 26 - Current best internal CV score: 0.7406269268894125
#
# Generation 27 - Current best internal CV score: 0.7406269268894125
#
# Generation 28 - Current best internal CV score: 0.7406269268894125
#
# Generation 29 - Current best internal CV score: 0.7406269268894125
#
# 5.05 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: ExtraTreesClassifier(OneHotEncoder(SelectPercentile(input_matrix, percentile=63), minimum_fraction=0.15, sparse=False, threshold=10), bootstrap=False, criterion=gini, max_features=0.8, min_samples_leaf=2, min_samples_split=9, n_estimators=100)
#
# Generation 1 - Current best internal CV score: 0.6931698654398658
#
# Generation 2 - Current best internal CV score: 0.6937213037420835
#
# Generation 3 - Current best internal CV score: 0.6994917901566049
#
# Generation 4 - Current best internal CV score: 0.7110528907472972
#
# Generation 5 - Current best internal CV score: 0.7110528907472972
#
# Generation 6 - Current best internal CV score: 0.7110528907472972
#
# Generation 7 - Current best internal CV score: 0.7110528907472972
#
# Generation 8 - Current best internal CV score: 0.7110528907472972
#
# Generation 9 - Current best internal CV score: 0.7148795611031511
#
# Generation 10 - Current best internal CV score: 0.7148795611031511
#
# Generation 11 - Current best internal CV score: 0.7148795611031511
#
# Generation 12 - Current best internal CV score: 0.7148795611031511
#
# Generation 13 - Current best internal CV score: 0.7227899600817291
#
# Generation 14 - Current best internal CV score: 0.7227899600817291
#
# Generation 15 - Current best internal CV score: 0.7227899600817291
#
# Generation 16 - Current best internal CV score: 0.7227899600817291
#
# 5.44 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: RandomForestClassifier(ZeroCount(ZeroCount(input_matrix)), bootstrap=False, criterion=gini, max_features=0.7000000000000001, min_samples_leaf=20, min_samples_split=17, n_estimators=100)
#
# Generation 1 - Current best internal CV score: 0.7215429937326234
#
# Generation 2 - Current best internal CV score: 0.7215429937326234
#
# Generation 3 - Current best internal CV score: 0.7215429937326234
#
# Generation 4 - Current best internal CV score: 0.7215429937326234
#
# Generation 5 - Current best internal CV score: 0.7215429937326234
#
# Generation 6 - Current best internal CV score: 0.7245231556104207
#
# Generation 7 - Current best internal CV score: 0.7245231556104207
#
# Generation 8 - Current best internal CV score: 0.7245231556104207
#
# Generation 9 - Current best internal CV score: 0.7245231556104207
#
# Generation 10 - Current best internal CV score: 0.7245231556104207
#
# 5.21 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: GaussianNB(SelectPercentile(RandomForestClassifier(input_matrix, bootstrap=True, criterion=entropy, max_features=0.2, min_samples_leaf=15, min_samples_split=13, n_estimators=100), percentile=22))
#
# Generation 1 - Current best internal CV score: 0.712690887031775
#
# Generation 2 - Current best internal CV score: 0.712690887031775
#
# Generation 3 - Current best internal CV score: 0.7139055284603852
#
# Generation 4 - Current best internal CV score: 0.7139055284603852
#
# Generation 5 - Current best internal CV score: 0.7139055284603852
#
# Generation 6 - Current best internal CV score: 0.7190059930420585
#
# Generation 7 - Current best internal CV score: 0.7190059930420585
#
# Generation 8 - Current best internal CV score: 0.7190059930420585
#
# Generation 9 - Current best internal CV score: 0.7190059930420585
#
# Generation 10 - Current best internal CV score: 0.7190499716621297
#
# Generation 11 - Current best internal CV score: 0.7190499716621297
#
# Generation 12 - Current best internal CV score: 0.7194004076448973
#
# Generation 13 - Current best internal CV score: 0.7235498991841383
#
# Generation 14 - Current best internal CV score: 0.7235498991841383
#
# Generation 15 - Current best internal CV score: 0.7235498991841383
#
# Generation 16 - Current best internal CV score: 0.7252973218327028
#
# 5.27 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: XGBClassifier(ExtraTreesClassifier(input_matrix, bootstrap=False, criterion=gini, max_features=0.9500000000000001, min_samples_leaf=7, min_samples_split=8, n_estimators=100), learning_rate=0.001, max_depth=9, min_child_weight=9, n_estimators=100, n_jobs=1, subsample=0.45, verbosity=0)
#
# Weighted F1-score: 0.7503638398111298
#
# End of the TPOT system execution: 2023-01-14 11:38:45.413970

# %%
tpot_X2 = run_tpot(X2_train, y2_train, max_time_mins=20)

# Save the model
tpot_X2.export('tpot_models/tpot_X2.py')

# Save the model as pickle
with open("./tpot_model_X2.pickle", "wb") as f:
    pickle.dump({"template": tpot_X2.fitted_pipeline_, "_imputed": tpot_X2._imputed}, f)
# Out:
# Start TPOT:  2023-01-13 23:53:58.019243 Time Limit per Fold: 5min
# Estimated end: 2023-01-14 00:13:58.019243
#
#
# Generation 1 - Current best internal CV score: 0.6235294218128227
#
# Generation 2 - Current best internal CV score: 0.6265997946336901
#
# Generation 3 - Current best internal CV score: 0.6381670999753408
#
# Generation 4 - Current best internal CV score: 0.6381670999753408
#
# Generation 5 - Current best internal CV score: 0.6381670999753408
#
# Generation 6 - Current best internal CV score: 0.6381670999753408
#
# Generation 7 - Current best internal CV score: 0.6381670999753408
#
# Generation 8 - Current best internal CV score: 0.6381670999753408
#
# Generation 9 - Current best internal CV score: 0.6381670999753408
#
# Generation 10 - Current best internal CV score: 0.6416186073455711
#
# Generation 11 - Current best internal CV score: 0.6416186073455711
#
# Generation 12 - Current best internal CV score: 0.6416397610448243
#
# Generation 13 - Current best internal CV score: 0.6416397610448243
#
# Generation 14 - Current best internal CV score: 0.6428966355461494
#
# Generation 15 - Current best internal CV score: 0.6475253783977333
#
# Generation 16 - Current best internal CV score: 0.6475253783977333
#
# Generation 17 - Current best internal CV score: 0.6475253783977333
#
# Generation 18 - Current best internal CV score: 0.6475253783977333
#
# Generation 19 - Current best internal CV score: 0.6475253783977333
#
# Generation 20 - Current best internal CV score: 0.6475253783977333
#
# Generation 21 - Current best internal CV score: 0.6475253783977333
#
# Generation 22 - Current best internal CV score: 0.6475253783977333
#
# Generation 23 - Current best internal CV score: 0.6475253783977333
#
# Generation 24 - Current best internal CV score: 0.6475253783977333
#
# Generation 25 - Current best internal CV score: 0.6510067669631576
#
# Generation 26 - Current best internal CV score: 0.6510067669631576
#
# Generation 27 - Current best internal CV score: 0.6510067669631576
#
# Generation 28 - Current best internal CV score: 0.6510067669631576
#
# Generation 29 - Current best internal CV score: 0.6510067669631576
#
# Generation 30 - Current best internal CV score: 0.6510067669631576
#
# Generation 31 - Current best internal CV score: 0.6510067669631576
#
# 5.04 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: XGBClassifier(RFE(input_matrix, criterion=entropy, max_features=0.8, n_estimators=100, step=0.15000000000000002), learning_rate=0.01, max_depth=10, min_child_weight=19, n_estimators=100, n_jobs=1, subsample=0.9500000000000001, verbosity=0)
#
# Generation 1 - Current best internal CV score: 0.6455964337301954
#
# Generation 2 - Current best internal CV score: 0.6455964337301954
#
# Generation 3 - Current best internal CV score: 0.6455964337301954
#
# Generation 4 - Current best internal CV score: 0.6465451516789134
#
# Generation 5 - Current best internal CV score: 0.6517069158636557
#
# Generation 6 - Current best internal CV score: 0.6517069158636557
#
# Generation 7 - Current best internal CV score: 0.6517069158636557
#
# Generation 8 - Current best internal CV score: 0.6517069158636557
#
# Generation 9 - Current best internal CV score: 0.6517069158636557
#
# Generation 10 - Current best internal CV score: 0.6519459555996352
#
# Generation 11 - Current best internal CV score: 0.6519459555996352
#
# Generation 12 - Current best internal CV score: 0.6543206244705628
#
# Generation 13 - Current best internal CV score: 0.6543206244705628
#
# Generation 14 - Current best internal CV score: 0.6543206244705628
#
# Generation 15 - Current best internal CV score: 0.6543206244705628
#
# Generation 16 - Current best internal CV score: 0.659087731131668
#
# Generation 17 - Current best internal CV score: 0.659087731131668
#
# Generation 18 - Current best internal CV score: 0.659087731131668
#
# Generation 19 - Current best internal CV score: 0.659087731131668
#
# Generation 20 - Current best internal CV score: 0.659087731131668
#
# Generation 21 - Current best internal CV score: 0.659087731131668
#
# Generation 22 - Current best internal CV score: 0.659087731131668
#
# Generation 23 - Current best internal CV score: 0.659087731131668
#
# Generation 24 - Current best internal CV score: 0.6658657114487241
#
# Generation 25 - Current best internal CV score: 0.6728086943996063
#
# Generation 26 - Current best internal CV score: 0.6728086943996063
#
# Generation 27 - Current best internal CV score: 0.6728086943996063
#
# Generation 28 - Current best internal CV score: 0.673380000985008
#
# Generation 29 - Current best internal CV score: 0.673380000985008
#
# Generation 30 - Current best internal CV score: 0.6743417737214739
#
# Generation 31 - Current best internal CV score: 0.6815462153226164
#
# Generation 32 - Current best internal CV score: 0.6815462153226164
#
# Generation 33 - Current best internal CV score: 0.6841894875805548
#
# Generation 34 - Current best internal CV score: 0.6841894875805548
#
# Generation 35 - Current best internal CV score: 0.6841894875805548
#
# Generation 36 - Current best internal CV score: 0.6841894875805548
#
# Generation 37 - Current best internal CV score: 0.6841894875805548
#
# Generation 38 - Current best internal CV score: 0.6841894875805548
#
# 5.04 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: XGBClassifier(ZeroCount(SGDClassifier(input_matrix, alpha=0.001, eta0=0.1, fit_intercept=True, l1_ratio=0.25, learning_rate=constant, loss=log, penalty=elasticnet, power_t=50.0)), learning_rate=0.1, max_depth=8, min_child_weight=13, n_estimators=100, n_jobs=1, subsample=0.6000000000000001, verbosity=0)
#
# Generation 1 - Current best internal CV score: 0.6075292521103488
#
# Generation 2 - Current best internal CV score: 0.6340527487344534
#
# Generation 3 - Current best internal CV score: 0.6340527487344534
#
# Generation 4 - Current best internal CV score: 0.6340527487344534
#
# Generation 5 - Current best internal CV score: 0.6350961745676951
#
# Generation 6 - Current best internal CV score: 0.6350961745676951
#
# Generation 7 - Current best internal CV score: 0.6350961745676951
#
# Generation 8 - Current best internal CV score: 0.6350961745676951
#
# Generation 9 - Current best internal CV score: 0.6350961745676951
#
# Generation 10 - Current best internal CV score: 0.6379788701859901
#
# Generation 11 - Current best internal CV score: 0.6379788701859901
#
# Generation 12 - Current best internal CV score: 0.6379788701859901
#
# Generation 13 - Current best internal CV score: 0.6379788701859901
#
# Generation 14 - Current best internal CV score: 0.6379788701859901
#
# Generation 15 - Current best internal CV score: 0.6379788701859901
#
# Generation 16 - Current best internal CV score: 0.6379788701859901
#
# Generation 17 - Current best internal CV score: 0.6447216395195777
#
# Generation 18 - Current best internal CV score: 0.6447216395195777
#
# Generation 19 - Current best internal CV score: 0.6447216395195777
#
# Generation 20 - Current best internal CV score: 0.6622850491702741
#
# Generation 21 - Current best internal CV score: 0.6622850491702741
#
# Generation 22 - Current best internal CV score: 0.6622850491702741
#
# Generation 23 - Current best internal CV score: 0.6622850491702741
#
# Generation 24 - Current best internal CV score: 0.6622850491702741
#
# Generation 25 - Current best internal CV score: 0.6622850491702741
#
# Generation 26 - Current best internal CV score: 0.6622850491702741
#
# Generation 27 - Current best internal CV score: 0.6622850491702741
#
# Generation 28 - Current best internal CV score: 0.6622850491702741
#
# Generation 29 - Current best internal CV score: 0.6622850491702741
#
# Generation 30 - Current best internal CV score: 0.6622850491702741
#
# Generation 31 - Current best internal CV score: 0.6622850491702741
#
# Generation 32 - Current best internal CV score: 0.6650324149002733
#
# Generation 33 - Current best internal CV score: 0.6650324149002733
#
# Generation 34 - Current best internal CV score: 0.6650324149002733
#
# Generation 35 - Current best internal CV score: 0.6654493848346098
#
# 5.20 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: RandomForestClassifier(SelectFwe(ExtraTreesClassifier(CombineDFs(input_matrix, input_matrix), bootstrap=True, criterion=gini, max_features=0.55, min_samples_leaf=2, min_samples_split=19, n_estimators=100), alpha=0.033), bootstrap=True, criterion=gini, max_features=0.35000000000000003, min_samples_leaf=13, min_samples_split=19, n_estimators=100)
#
# Generation 1 - Current best internal CV score: 0.640429602564782
#
# Generation 2 - Current best internal CV score: 0.640429602564782
#
# Generation 3 - Current best internal CV score: 0.6418098729489892
#
# Generation 4 - Current best internal CV score: 0.6585825186565396
#
# Generation 5 - Current best internal CV score: 0.6585825186565396
#
# Generation 6 - Current best internal CV score: 0.6585825186565396
#
# Generation 7 - Current best internal CV score: 0.6585825186565396
#
# Generation 8 - Current best internal CV score: 0.6585825186565396
#
# Generation 9 - Current best internal CV score: 0.6585825186565396
#
# Generation 10 - Current best internal CV score: 0.6585825186565396
#
# Generation 11 - Current best internal CV score: 0.6585825186565396
#
# Generation 12 - Current best internal CV score: 0.6585825186565396
#
# Generation 13 - Current best internal CV score: 0.6585825186565396
#
# Generation 14 - Current best internal CV score: 0.6585825186565396
#
# Generation 15 - Current best internal CV score: 0.6585825186565396
#
# Generation 16 - Current best internal CV score: 0.6585825186565396
#
# Generation 17 - Current best internal CV score: 0.6600788606168506
#
# Generation 18 - Current best internal CV score: 0.660539003859738
#
# Generation 19 - Current best internal CV score: 0.660539003859738
#
# Generation 20 - Current best internal CV score: 0.660539003859738
#
# Generation 21 - Current best internal CV score: 0.660539003859738
#
# Generation 22 - Current best internal CV score: 0.660539003859738
#
# Generation 23 - Current best internal CV score: 0.660539003859738
#
# Generation 24 - Current best internal CV score: 0.660539003859738
#
# Generation 25 - Current best internal CV score: 0.660539003859738
#
# 5.07 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: RandomForestClassifier(OneHotEncoder(MinMaxScaler(input_matrix), minimum_fraction=0.2, sparse=False, threshold=10), bootstrap=True, criterion=gini, max_features=0.2, min_samples_leaf=8, min_samples_split=4, n_estimators=100)
#
# Weighted F1-score: 0.6038505284424499
#
# End of the TPOT system execution: 2023-01-14 00:14:22.285246
