# %% [markdown]
# # Assignment
# This project aims to use AutoML to predict clinical outcomes using imaging and clinical variables. The imaging modality of interest is positron emission tomography (PET). We provide a data dictionary sheet that has an explanation for what each variable resembles.
#
# The outcome of interest to predict is MACE with heart failure (`o_mace` column). Variables to include in the model are highlighted in <font color='gold'>yellow </font>. (This includes the bare minimum of variables, avoiding known collinearity). Variables highlighted in <font color = 'blue'>blue</font> are variables that are known to be collinear, with some of the yellow-highlighted ones.
#
# As a **second step**, if you can please build another predictive model **using BOTH the <font color = 'gold'>yellow</font> and the <font color = 'blue'>blue</font> highlighted variables**, just to assess if some of the collinear variables may be more predictive than others. (This model will have a large number of variables in the model).
#
# Variables **not to be used** for building the model (may be used at a later point) are highlighted in <font color = 'grey'>grey</font>.
#
# One thing to note is the unindexed values for `lvmass`, `EF`, and `systolic/diastolic` volumes but not the indexed ones (indexed ones end with `_ind`). This is to avoid collinearity, too, so only include the indexed ones with the rest of the variables in the model for model 2 but not model 1.
#
# Once the model is built, we need to explain the outcome based on different groups of interest (i.e, different age groups, different race/ethnicity groups ). For interpretability, we can explore different options; LIME, SHAP,..etc.

# %% [markdown]
# # Setup

# %%
# Install the packages defined in `requirements.txt`
# !pip install -r requirements.txt

# %%
# Working with data frames
import pandas as pd
import numpy as np
import sklearn.datasets

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from tpot import TPOTClassifier

# Misc
import pickle
import datetime
import warnings
#from google.colab.output import eval_js
#eval_js('google.colab.output.setIframeHeight("500")') # output cell size in GC
warnings.filterwarnings('ignore') # disable warnings

# %%
# Include a custom function for performance metrics (used later)

from sklearn.metrics import accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score, roc_auc_score

def classification_metrics(y_true, y_pred):
    """A helper function for computing and printing
    several relevant classification metrics. 

    'weighted': Calculate metrics for each label, and find their average, 
    weighted by support (the number of true instances for each label).
    
    Args:
        y_true (np.array): actual labels
        y_pred (np.array): predicted labels
    Prints:
        All metrics on a separate line.      
    """
    accuracy = accuracy_score(y_true, y_pred)
    precision_weighted = precision_score(y_true, y_pred, average='weighted')
    recall_weighted = recall_score(y_true, y_pred, average = 'weighted')
    f1_score_weighted = f1_score(y_true, y_pred, average = 'weighted')
    roc_auc_weighted = roc_auc_score(y_true, y_pred, average = 'weighted')
    print(f'Accuracy: {accuracy}')
    print(f'Precision (weighted): {precision_weighted}')
    print(f'Recall (weighted): {recall_weighted}')
    print(f'F1-score (weighted): {f1_score_weighted}')
    print(f'ROC-AUC (weighted): {roc_auc_weighted}')

# %% [markdown]
# # Data Import
# Because the data are confidential, we are not allowed to include it in the repository. Hence, we import it from a local machine outside of the working directory (the present repository).
#
# Of note, we mport two sheets from the Excel workbook: the data and the legend (data dictionary) sheets. The latter is used for, e.g., excluding the <font color='grey'> grey </font> features, as well as building models without and with <font color='blue'> blue </font> features.

# %%
df_raw = pd.read_excel('df_project2.xlsx', sheet_name = 'complete_db') # read the df from outside the directory 
df_legend = pd.read_excel('df_project2.xlsx', sheet_name = 'data_dictionary') # read the data dictionary

df_legend.head()
# Out:
#    position          name_col              name   type  isnumeric  format  \
# 0         1  annon_serial_num  annon_serial_num  float          1   %9.0g
# 1         2            sd_age            sd_age   byte          1  %10.0g
# 2         3            sd_sex            sd_sex   str6          0     %9s
# 3         4   sd_race_unified   sd_race_unified  str38          0    %38s
# 4         5   sd_ethn_unified   sd_ethn_unified  str12          0    %12s
#
#   vallab              varlab         Explanation column_color  no_yes_vars
# 0    NaN  group(id pet_date)                 NaN       yellow          0.0
# 1    NaN              sd_age         patient age       yellow          0.0
# 2    NaN              sd_sex      patient gender       yellow          0.0
# 3    NaN     sd_race_unified        patient race       yellow          0.0
# 4    NaN     sd_ethn_unified  patient ethinicity         blue          0.0

# %% [markdown]
# ## Basic Data Preprocessing

# %%
# remove non-_ind columns
print(f"df_raw dimensions before removing non-'_ind' cols:{df_raw.shape} ")
# Find columns that end with '_ind'
ind_cols = df_raw.columns[df_raw.columns.str.endswith('_ind')]
# Find column names that have both 'raw' and 'index' column
colnames_non_ind = ind_cols.str.replace('_ind', '')

# Remove the non-_ind columns
remove_yellows = []
for col in colnames_non_ind:
  all_cols = df_raw.columns[df_raw.columns.str.startswith(col)]
  for col2 in all_cols:
    if '_ind' in col2:
      pass
    else:
      remove_yellows.append(col2)
      df_raw = df_raw.drop(columns = [col2])
print(f"df_raw dimensions after removing non-'_ind' cols:{df_raw.shape} ")

# Find the column names based on color
grey_cols = df_legend[df_legend['column_color'] == 'grey']['name_col']
blue_cols = df_legend[df_legend['column_color'] == 'blue']['name_col']
yellow_cols = df_legend[df_legend['column_color'] == 'yellow']['name_col']
# Remove the non-_ind cols
yellow_cols = yellow_cols[~yellow_cols.isin(remove_yellows)].reset_index(drop = True)
green_cols = df_legend[df_legend['column_color'] == 'green']['name_col']


# Find the binary No/Yes vars (to be replaced with 0/1)
yes_no_cols = df_legend[df_legend['no_yes_vars'] == 1]['name_col'].values
df_raw[yes_no_cols] = df_raw[yes_no_cols].replace(to_replace=['No', 
                                                              'Yes'], 
                                                  value=[0, 1]) # replace No-Yes to 0-1

# Binarize 'sex' variable
df_raw['sd_sex'] = df_raw['sd_sex'].replace(to_replace=['Male', 
                                                        'Female'], 
                                            value=[0, 1])

# Binarize 'pharm_stressor'
df_raw['pharm_stressor'] = df_raw['pharm_stressor'].replace(to_replace=['Adenosine', 
                                                                        'Regadenoson'], 
                                                            value=[0, 1])

# Convert 'sd_bmi_cat' and 'cac_cat' to ordered numeric variable
df_raw['sd_bmi_cat'] = df_raw['sd_bmi_cat'].replace(to_replace = ['Underweight (<18.5kg/m2)',
                                           'Normal (18.5-25kg/m2)',
                                           'Overweight (25-30kg/m2)',
                                           'Obese (≥30kg/m2)'
                                           ],
                             value = [1,2,3,4])

df_raw['cac_cat'] = df_raw['cac_cat'].replace(to_replace = ['CACS 0', 
                                        'CACS 1-99','CACS 100-399',
                                        'CACS 400-999', 'CACS ≥1000'],
                          value = [0,1,2,3,4])
# Out:
# df_raw dimensions before removing non-'_ind' cols:(4323, 109)
# df_raw dimensions after removing non-'_ind' cols:(4323, 105)

# %% [markdown]
# ## Dataset Extraction

# %%
# Extract the target
target = df_raw[green_cols]['o_mace']

# Create the yellow X features df (X1)
X1 = df_raw[yellow_cols]

# Create the yellow-blue X features df (X2)
X2 = df_raw.drop(columns = grey_cols.append(green_cols))

# Drop the ID-col (it's sequential and can be easily retrieved)
X1 = X1.drop(columns = 'annon_serial_num')
X2 = X2.drop(columns = 'annon_serial_num')

# Convert `object` vars to dummies (TPOT might not deal well with cat-vars)
X1 = pd.get_dummies(X1, drop_first = True)
X2 = pd.get_dummies(X2, drop_first = True)


# Print the dimensions
print(f'Initial df dimensions: {df_raw.shape}')
print(f'Yellow X df dimensions: {X1.shape}')
print(f'Yellow-blue X df dimensions: {X2.shape}')
print(f'target dimensions: {target.shape}')
# Out:
# Initial df dimensions: (4323, 105)
# Yellow X df dimensions: (4323, 60)
# Yellow-blue X df dimensions: (4323, 84)
# target dimensions: (4323,)

# %%
# saving data for interpretability task
#X1.to_csv('X1.csv', index=False)
#X2.to_csv('X2.csv', index=False)
#target.to_csv('target.csv', index=False)

# %% [markdown]
# ## Check for missing values and other data characteristics

# %%
print('Number of missing values:')
print()
print(f'Target y: {target.isnull().sum()}')
#print(f'Target X1: {X1.isnull().sum()}')
#print(f'Target X2: {X2.isnull().sum()}')
# Out:
# Number of missing values:
#
# Target y: 0

# %% [markdown]
# # Train-test split

# %%
# Train-test split for yellow X
X1_train, X1_val, y1_train, y1_val = train_test_split(X1, target, test_size=0.3, random_state=42)

# Train-test split for yellow-blue X
X2_train, X2_val, y2_train, y2_val = train_test_split(X2, target, test_size=0.3, random_state=42)

# %%
# Data to pickle (for later retrievalb)
X1_train.to_pickle("./X1_train.pkl")
y1_train.to_pickle("./y1_train.pkl")
X2_train.to_pickle("./X2_train.pkl")
y2_train.to_pickle("./y2_train.pkl")
X1_val.to_pickle("./X1_val.pkl")
y1_val.to_pickle("./y1_val.pkl")
X2_val.to_pickle("./X2_val.pkl")
y2_val.to_pickle("./y2_val.pkl")

# %% [markdown]
# # TPOT
# - Maybe also see this tutorial: https://medium.com/analytics-vidhya/learn-to-use-tpot-an-automl-tool-4c52148c2bc9
# - A paper using TPOT for medical classification: https://academic.oup.com/bioinformatics/article/36/6/1772/5614811
# - More about `TPOTClassifier` class args: http://epistasislab.github.io/tpot/using/
# - TPOT Github repo: https://github.com/EpistasisLab/tpot

# %% [markdown]
# # 1st `tpot` run

# %%
def build_tpot(X_train, y_train, max_time_mins = None):

  # Initialize the TPOT framework for classification.
  tpot = TPOTClassifier(
    generations=100, # Number of iterations to run the pipeline optimization process.
    population_size=20, # Number of individuals to retain in the GP population every generation. 
    scoring = 'f1_weighted', # use the wieghted F1 score
    cv = 5,
    n_jobs = -1, # all CPUs are used.
    max_time_mins = max_time_mins,
    max_eval_time_mins = 5,
    random_state = 42,
    verbosity = 2
  )

  # Fit the framework.
  tpot.fit(X_train, y_train)

  return tpot


def run_tpot(X, y, max_time_mins, n_splits=3):

  # Limit time to be equally between all fold and
  # also the final run on the entire dataset.
  time_limit = max(1, max_time_mins // (n_splits + 1))

  # Informative runtime information.
  start_run = datetime.datetime.now()
  estimated_end = start_run + datetime.timedelta(minutes=time_limit*(n_splits + 1))
  print(f'Start TPOT:  {start_run} Time Limit per Fold: {time_limit}min')
  print(f'Estimated end: {estimated_end}\n')

  skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
  scores = []

  # Perform startified cross validation.s
  for train_index, val_index in skf.split(X, y):

    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    tpot = build_tpot(X_train, y_train, time_limit)

    # Predictions and weighted F1-score.
    y_pred = tpot.predict(X_val)
    score = f1_score(y_pred, y_val, average='weighted')
    scores.append(score)

  # Building the final TPOT model on all samples.
  tpot = build_tpot(X, y, time_limit)
  avg_score = sum(scores) / len(scores)

  print()
  print(f'Weighted F1-score: {avg_score}\n')
  print(f'End of the TPOT system execution: {datetime.datetime.now()}\n')

  return tpot

# %%
tpot_X1 = run_tpot(X1_train, y1_train, max_time_mins=60*5)

# Save the model
tpot_X1.export('tpot_models/tpot_X1.py')

# Save the model as pickle
with open("./tpot_model_X1.pickle", "wb") as f:
    pickle.dump({"template": tpot_X1.fitted_pipeline_, "_imputed": tpot_X1._imputed}, f)
# Out:
# Start TPOT:  2023-01-07 22:24:50.773927 Time Limit per Fold: 75min
# Estimated end: 2023-01-08 03:24:50.773927
#
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.9079489919291813
#
# Generation 2 - Current best internal CV score: 0.9094229645281354
#
# Generation 3 - Current best internal CV score: 0.9094229645281354
#
# Generation 4 - Current best internal CV score: 0.9094229645281354
#
# Generation 5 - Current best internal CV score: 0.9101289155000887
#
# Generation 6 - Current best internal CV score: 0.9101289155000887
#
# Generation 7 - Current best internal CV score: 0.9111347299540677
#
# Generation 8 - Current best internal CV score: 0.9124179869325169
#
# Generation 9 - Current best internal CV score: 0.9124179869325169
#
# Generation 10 - Current best internal CV score: 0.9124179869325169
#
# Generation 11 - Current best internal CV score: 0.9124179869325169
#
# Generation 12 - Current best internal CV score: 0.9124179869325169
#
# Generation 13 - Current best internal CV score: 0.9124179869325169
#
# Generation 14 - Current best internal CV score: 0.9124179869325169
#
# Generation 15 - Current best internal CV score: 0.9124179869325169
#
# Generation 16 - Current best internal CV score: 0.9126272935843567
#
# Generation 17 - Current best internal CV score: 0.9126272935843567
#
# Generation 18 - Current best internal CV score: 0.9126272935843567
#
# Generation 19 - Current best internal CV score: 0.9126272935843567
#
# Generation 20 - Current best internal CV score: 0.9126272935843567
#
# Generation 21 - Current best internal CV score: 0.9126272935843567
#
# Generation 22 - Current best internal CV score: 0.913826924000942
#
# Generation 23 - Current best internal CV score: 0.913826924000942
#
# Generation 24 - Current best internal CV score: 0.913826924000942
#
# Generation 25 - Current best internal CV score: 0.913826924000942
#
# Generation 26 - Current best internal CV score: 0.913826924000942
#
# Generation 27 - Current best internal CV score: 0.913826924000942
#
# Generation 28 - Current best internal CV score: 0.913826924000942
#
# Generation 29 - Current best internal CV score: 0.913826924000942
#
# Generation 30 - Current best internal CV score: 0.9152208880934145
#
# Generation 31 - Current best internal CV score: 0.9152208880934145
#
# Generation 32 - Current best internal CV score: 0.9152208880934145
#
# Generation 33 - Current best internal CV score: 0.9152208880934145
#
# Generation 34 - Current best internal CV score: 0.9152208880934145
#
# Generation 35 - Current best internal CV score: 0.9152208880934145
#
# Generation 36 - Current best internal CV score: 0.9152208880934145
#
# Generation 37 - Current best internal CV score: 0.9152208880934145
#
# Generation 38 - Current best internal CV score: 0.9152208880934145
#
# Generation 39 - Current best internal CV score: 0.9152208880934145
#
# Generation 40 - Current best internal CV score: 0.9152208880934145
#
# Generation 41 - Current best internal CV score: 0.9152208880934145
#
# Generation 42 - Current best internal CV score: 0.9152208880934145
#
# Generation 43 - Current best internal CV score: 0.9152208880934145
#
# Generation 44 - Current best internal CV score: 0.9152208880934145
#
# Generation 45 - Current best internal CV score: 0.915577561241338
#
# Generation 46 - Current best internal CV score: 0.9166086257855284
#
# Generation 47 - Current best internal CV score: 0.9166086257855284
#
# Generation 48 - Current best internal CV score: 0.9166086257855284
#
# Generation 49 - Current best internal CV score: 0.9166086257855284
#
# 79.28 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: RandomForestClassifier(RFE(VarianceThreshold(OneHotEncoder(input_matrix, minimum_fraction=0.25, sparse=False, threshold=10), threshold=0.005), criterion=gini, max_features=0.7000000000000001, n_estimators=100, step=0.35000000000000003), bootstrap=True, criterion=gini, max_features=0.6000000000000001, min_samples_leaf=1, min_samples_split=13, n_estimators=100)
# Imputing missing values in feature set
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.9098295671052952
#
# Generation 2 - Current best internal CV score: 0.9100439393590694
#
# Generation 3 - Current best internal CV score: 0.9110735833799419
#
# Generation 4 - Current best internal CV score: 0.9111288017907715
#
# Generation 5 - Current best internal CV score: 0.9111288017907715
#
# Generation 6 - Current best internal CV score: 0.9111288017907715
#
# Generation 7 - Current best internal CV score: 0.9111288017907715
#
# Generation 8 - Current best internal CV score: 0.9111288017907715
#
# Generation 9 - Current best internal CV score: 0.9111288017907715
#
# Generation 10 - Current best internal CV score: 0.9111288017907715
#
# Generation 11 - Current best internal CV score: 0.9111288017907715
#
# Generation 12 - Current best internal CV score: 0.9117018470021396
#
# Generation 13 - Current best internal CV score: 0.9117018470021396
#
# Generation 14 - Current best internal CV score: 0.9117018470021396
#
# Generation 15 - Current best internal CV score: 0.9117737318140813
#
# Generation 16 - Current best internal CV score: 0.9117737318140813
#
# Generation 17 - Current best internal CV score: 0.9117737318140813
#
# Generation 18 - Current best internal CV score: 0.9119164887112368
#
# Generation 19 - Current best internal CV score: 0.9119164887112368
#
# Generation 20 - Current best internal CV score: 0.9123043882849174
#
# Generation 21 - Current best internal CV score: 0.9123608037742675
#
# Generation 22 - Current best internal CV score: 0.9123608037742675
#
# Generation 23 - Current best internal CV score: 0.9123608037742675
#
# Generation 24 - Current best internal CV score: 0.9123608037742675
#
# Generation 25 - Current best internal CV score: 0.9123608037742675
#
# Generation 26 - Current best internal CV score: 0.9134456819719539
#
# Generation 27 - Current best internal CV score: 0.9134456819719539
#
# Generation 28 - Current best internal CV score: 0.9134456819719539
#
# Generation 29 - Current best internal CV score: 0.9151912986952351
#
# Generation 30 - Current best internal CV score: 0.9151912986952351
#
# Generation 31 - Current best internal CV score: 0.9151912986952351
#
# Generation 32 - Current best internal CV score: 0.9151912986952351
#
# Generation 33 - Current best internal CV score: 0.9151912986952351
#
# Generation 34 - Current best internal CV score: 0.9151912986952351
#
# Generation 35 - Current best internal CV score: 0.9151912986952351
#
# Generation 36 - Current best internal CV score: 0.9151912986952351
#
# Generation 37 - Current best internal CV score: 0.9151912986952351
#
# Generation 38 - Current best internal CV score: 0.9151912986952351
#
# Generation 39 - Current best internal CV score: 0.9151912986952351
#
# Generation 40 - Current best internal CV score: 0.9151912986952351
#
# Generation 41 - Current best internal CV score: 0.9151912986952351
#
# Generation 42 - Current best internal CV score: 0.9153226086019256
#
# Generation 43 - Current best internal CV score: 0.9154976830263344
#
# Generation 44 - Current best internal CV score: 0.9154976830263344
#
# Generation 45 - Current best internal CV score: 0.9156016949246304
#
# Generation 46 - Current best internal CV score: 0.9156016949246304
#
# Generation 47 - Current best internal CV score: 0.9171149914041123
#
# Generation 48 - Current best internal CV score: 0.9171149914041123
#
# Generation 49 - Current best internal CV score: 0.9171149914041123
#
# Generation 50 - Current best internal CV score: 0.9171149914041123
#
# Generation 51 - Current best internal CV score: 0.9171149914041123
#
# 75.58 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: XGBClassifier(GradientBoostingClassifier(CombineDFs(input_matrix, input_matrix), learning_rate=0.01, max_depth=2, max_features=0.8500000000000001, min_samples_leaf=6, min_samples_split=9, n_estimators=100, subsample=0.6000000000000001), learning_rate=0.01, max_depth=9, min_child_weight=2, n_estimators=100, n_jobs=1, subsample=0.7000000000000001, verbosity=0)
# Imputing missing values in feature set
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.8984741975113522
#
# Generation 2 - Current best internal CV score: 0.9015802006506399
#
# Generation 3 - Current best internal CV score: 0.9015802006506399
#
# Generation 4 - Current best internal CV score: 0.9015802006506399
#
# Generation 5 - Current best internal CV score: 0.9015802006506399
#
# Generation 6 - Current best internal CV score: 0.9030224951437666
#
# Generation 7 - Current best internal CV score: 0.9030224951437666
#
# Generation 8 - Current best internal CV score: 0.9030224951437666
#
# Generation 9 - Current best internal CV score: 0.9034291711820177
#
# Generation 10 - Current best internal CV score: 0.9040094671950591
#
# Generation 11 - Current best internal CV score: 0.9066217232844508
#
# Generation 12 - Current best internal CV score: 0.9066217232844508
#
# Generation 13 - Current best internal CV score: 0.9066217232844508
#
# Generation 14 - Current best internal CV score: 0.9083357481660153
#
# Generation 15 - Current best internal CV score: 0.9090230576867409
#
# Generation 16 - Current best internal CV score: 0.9090230576867409
#
# Generation 17 - Current best internal CV score: 0.9090230576867409
#
# Generation 18 - Current best internal CV score: 0.9090230576867409
#
# Generation 19 - Current best internal CV score: 0.9095281209104604
#
# Generation 20 - Current best internal CV score: 0.9095281209104604
#
# Generation 21 - Current best internal CV score: 0.9101085943048023
#
# Generation 22 - Current best internal CV score: 0.9101646458853055
#
# Generation 23 - Current best internal CV score: 0.9105362509660921
#
# Generation 24 - Current best internal CV score: 0.9105362509660921
#
# Generation 25 - Current best internal CV score: 0.9121733491106697
#
# Generation 26 - Current best internal CV score: 0.9121733491106697
#
# Generation 27 - Current best internal CV score: 0.9121733491106697
#
# Generation 28 - Current best internal CV score: 0.9121733491106697
#
# Generation 29 - Current best internal CV score: 0.9121733491106697
#
# Generation 30 - Current best internal CV score: 0.9121733491106697
#
# Generation 31 - Current best internal CV score: 0.9124121173021607
#
# Generation 32 - Current best internal CV score: 0.9124553624833102
#
# Generation 33 - Current best internal CV score: 0.9124553624833102
#
# Generation 34 - Current best internal CV score: 0.9124553624833102
#
# Generation 35 - Current best internal CV score: 0.9154208785306961
#
# Generation 36 - Current best internal CV score: 0.9154208785306961
#
# Generation 37 - Current best internal CV score: 0.9154208785306961
#
# Generation 38 - Current best internal CV score: 0.9154208785306961
#
# Generation 39 - Current best internal CV score: 0.9154208785306961
#
# Generation 40 - Current best internal CV score: 0.9154208785306961
#
# Generation 41 - Current best internal CV score: 0.9154208785306961
#
# Generation 42 - Current best internal CV score: 0.9154208785306961
#
# Generation 43 - Current best internal CV score: 0.9154208785306961
#
# Generation 44 - Current best internal CV score: 0.9154208785306961
#
# Generation 45 - Current best internal CV score: 0.9154208785306961
#
# Generation 46 - Current best internal CV score: 0.9154208785306961
#
# Generation 47 - Current best internal CV score: 0.9154208785306961
#
# Generation 48 - Current best internal CV score: 0.9154208785306961
#
# Generation 49 - Current best internal CV score: 0.9154208785306961
#
# Generation 50 - Current best internal CV score: 0.9154208785306961
#
# Generation 51 - Current best internal CV score: 0.9154208785306961
#
# Generation 52 - Current best internal CV score: 0.9154208785306961
#
# Generation 53 - Current best internal CV score: 0.9154208785306961
#
# Generation 54 - Current best internal CV score: 0.9154208785306961
#
# Generation 55 - Current best internal CV score: 0.9154208785306961
#
# Generation 56 - Current best internal CV score: 0.9154208785306961
#
# Generation 57 - Current best internal CV score: 0.9154208785306961
#
# Generation 58 - Current best internal CV score: 0.9157186816423051
#
# Generation 59 - Current best internal CV score: 0.9157186816423051
#
# Generation 60 - Current best internal CV score: 0.9157186816423051
#
# Generation 61 - Current best internal CV score: 0.9157186816423051
#
# Generation 62 - Current best internal CV score: 0.9157186816423051
#
# Generation 63 - Current best internal CV score: 0.9157186816423051
#
# Generation 64 - Current best internal CV score: 0.9157186816423051
#
# Generation 65 - Current best internal CV score: 0.9160753547902287
#
# Generation 66 - Current best internal CV score: 0.9160753547902287
#
# Generation 67 - Current best internal CV score: 0.9160753547902287
#
# Generation 68 - Current best internal CV score: 0.9160753547902287
#
# Generation 69 - Current best internal CV score: 0.9160753547902287
#
# Generation 70 - Current best internal CV score: 0.9160753547902287
#
# Generation 71 - Current best internal CV score: 0.9160753547902287
#
# Generation 72 - Current best internal CV score: 0.9160753547902287
#
# Generation 73 - Current best internal CV score: 0.9160753547902287
#
# Generation 74 - Current best internal CV score: 0.9160753547902287
#
# Generation 75 - Current best internal CV score: 0.9160753547902287
#
# Generation 76 - Current best internal CV score: 0.9160753547902287
#
# Generation 77 - Current best internal CV score: 0.9160753547902287
#
# Generation 78 - Current best internal CV score: 0.9160753547902287
#
# Generation 79 - Current best internal CV score: 0.9160753547902287
#
# Generation 80 - Current best internal CV score: 0.9160753547902287
#
# Generation 81 - Current best internal CV score: 0.9160753547902287
#
# Generation 82 - Current best internal CV score: 0.9160753547902287
#
# Generation 83 - Current best internal CV score: 0.9160753547902287
#
# Generation 84 - Current best internal CV score: 0.9160753547902287
#
# Generation 85 - Current best internal CV score: 0.9160753547902287
#
# Generation 86 - Current best internal CV score: 0.9160753547902287
#
# Generation 87 - Current best internal CV score: 0.9160753547902287
#
# Generation 88 - Current best internal CV score: 0.9160753547902287
#
# Generation 89 - Current best internal CV score: 0.9160753547902287
#
# Generation 90 - Current best internal CV score: 0.9160753547902287
#
# Generation 91 - Current best internal CV score: 0.9160753547902287
#
# Generation 92 - Current best internal CV score: 0.9160753547902287
#
# Generation 93 - Current best internal CV score: 0.9160753547902287
#
# Generation 94 - Current best internal CV score: 0.9160753547902287
#
# Generation 95 - Current best internal CV score: 0.9160753547902287
#
# Generation 96 - Current best internal CV score: 0.9160753547902287
#
# Generation 97 - Current best internal CV score: 0.9160753547902287
#
# Generation 98 - Current best internal CV score: 0.9160753547902287
#
# Generation 99 - Current best internal CV score: 0.9160753547902287
#
# Generation 100 - Current best internal CV score: 0.9160753547902287
#
# Best pipeline: RandomForestClassifier(SelectFwe(SelectPercentile(GradientBoostingClassifier(VarianceThreshold(input_matrix, threshold=0.001), learning_rate=0.1, max_depth=1, max_features=0.6500000000000001, min_samples_leaf=4, min_samples_split=16, n_estimators=100, subsample=0.45), percentile=55), alpha=0.008), bootstrap=False, criterion=entropy, max_features=0.2, min_samples_leaf=9, min_samples_split=4, n_estimators=100)
# Imputing missing values in feature set
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.9079409547223252
#
# Generation 2 - Current best internal CV score: 0.9083684248716406
#
# Generation 3 - Current best internal CV score: 0.9112739411571121
#
# Generation 4 - Current best internal CV score: 0.9112739411571121
#
# Generation 5 - Current best internal CV score: 0.9112739411571121
#
# Generation 6 - Current best internal CV score: 0.9112739411571121
#
# Generation 7 - Current best internal CV score: 0.9112739411571121
#
# Generation 8 - Current best internal CV score: 0.9112739411571121
#
# Generation 9 - Current best internal CV score: 0.9112739411571121
#
# Generation 10 - Current best internal CV score: 0.9112739411571121
#
# Generation 11 - Current best internal CV score: 0.9112739411571121
#
# Generation 12 - Current best internal CV score: 0.9112739411571121
#
# Generation 13 - Current best internal CV score: 0.9112739411571121
#
# Generation 14 - Current best internal CV score: 0.911911384026315
#
# Generation 15 - Current best internal CV score: 0.911911384026315
#
# Generation 16 - Current best internal CV score: 0.911911384026315
#
# Generation 17 - Current best internal CV score: 0.911911384026315
#
# Generation 18 - Current best internal CV score: 0.911911384026315
#
# Generation 19 - Current best internal CV score: 0.911911384026315
#
# Generation 20 - Current best internal CV score: 0.911911384026315
#
# Generation 21 - Current best internal CV score: 0.911911384026315
#
# Generation 22 - Current best internal CV score: 0.911911384026315
#
# Generation 23 - Current best internal CV score: 0.911911384026315
#
# Generation 24 - Current best internal CV score: 0.911911384026315
#
# Generation 25 - Current best internal CV score: 0.911911384026315
#
# Generation 26 - Current best internal CV score: 0.911911384026315
#
# Generation 27 - Current best internal CV score: 0.911911384026315
#
# Generation 28 - Current best internal CV score: 0.911911384026315
#
# Generation 29 - Current best internal CV score: 0.911911384026315
#
# Generation 30 - Current best internal CV score: 0.912508678022029
#
# Generation 31 - Current best internal CV score: 0.912508678022029
#
# Generation 32 - Current best internal CV score: 0.9125308909213763
#
# Generation 33 - Current best internal CV score: 0.9129794323661116
#
# Generation 34 - Current best internal CV score: 0.9137268183799765
#
# Generation 35 - Current best internal CV score: 0.9137268183799765
#
# Generation 36 - Current best internal CV score: 0.9137268183799765
#
# Generation 37 - Current best internal CV score: 0.9137268183799765
#
# Generation 38 - Current best internal CV score: 0.9137268183799765
#
# Generation 39 - Current best internal CV score: 0.9137268183799765
#
# Generation 40 - Current best internal CV score: 0.9137268183799765
#
# Generation 41 - Current best internal CV score: 0.9141211009118322
#
# Generation 42 - Current best internal CV score: 0.914500544994822
#
# Generation 43 - Current best internal CV score: 0.914500544994822
#
# Generation 44 - Current best internal CV score: 0.914500544994822
#
# Generation 45 - Current best internal CV score: 0.9145956595521127
#
# Generation 46 - Current best internal CV score: 0.9145956595521127
#
# Generation 47 - Current best internal CV score: 0.9145956595521127
#
# Generation 48 - Current best internal CV score: 0.9145956595521127
#
# Generation 49 - Current best internal CV score: 0.915828523415523
#
# Generation 50 - Current best internal CV score: 0.915828523415523
#
# Generation 51 - Current best internal CV score: 0.915828523415523
#
# Generation 52 - Current best internal CV score: 0.915828523415523
#
# Generation 53 - Current best internal CV score: 0.915828523415523
#
# Generation 54 - Current best internal CV score: 0.915828523415523
#
# Generation 55 - Current best internal CV score: 0.915828523415523
#
# Generation 56 - Current best internal CV score: 0.915828523415523
#
# Generation 57 - Current best internal CV score: 0.915828523415523
#
# Generation 58 - Current best internal CV score: 0.915828523415523
#
# Generation 59 - Current best internal CV score: 0.915828523415523
#
# Generation 60 - Current best internal CV score: 0.915828523415523
#
# Generation 61 - Current best internal CV score: 0.915828523415523
#
# Generation 62 - Current best internal CV score: 0.915828523415523
#
# Generation 63 - Current best internal CV score: 0.915828523415523
#
# Generation 64 - Current best internal CV score: 0.915828523415523
#
# Generation 65 - Current best internal CV score: 0.915828523415523
#
# Generation 66 - Current best internal CV score: 0.915828523415523
#
# Generation 67 - Current best internal CV score: 0.915828523415523
#
# Generation 68 - Current best internal CV score: 0.915828523415523
#
# Generation 69 - Current best internal CV score: 0.915828523415523
#
# Generation 70 - Current best internal CV score: 0.915828523415523
#
# Generation 71 - Current best internal CV score: 0.915828523415523
#
# Generation 72 - Current best internal CV score: 0.915828523415523
#
# Generation 73 - Current best internal CV score: 0.915828523415523
#
# Generation 74 - Current best internal CV score: 0.915828523415523
#
# Generation 75 - Current best internal CV score: 0.915828523415523
#
# Generation 76 - Current best internal CV score: 0.915828523415523
#
# Generation 77 - Current best internal CV score: 0.915828523415523
#
# Generation 78 - Current best internal CV score: 0.915828523415523
#
# Generation 79 - Current best internal CV score: 0.915828523415523
#
# Generation 80 - Current best internal CV score: 0.915828523415523
#
# Generation 81 - Current best internal CV score: 0.915828523415523
#
# Generation 82 - Current best internal CV score: 0.915828523415523
#
# Generation 83 - Current best internal CV score: 0.915828523415523
#
# Generation 84 - Current best internal CV score: 0.915828523415523
#
# Generation 85 - Current best internal CV score: 0.915828523415523
#
# Generation 86 - Current best internal CV score: 0.915828523415523
#
# Generation 87 - Current best internal CV score: 0.915828523415523
#
# Generation 88 - Current best internal CV score: 0.915828523415523
#
# Generation 89 - Current best internal CV score: 0.915828523415523
#
# Generation 90 - Current best internal CV score: 0.915828523415523
#
# Generation 91 - Current best internal CV score: 0.915828523415523
#
# Generation 92 - Current best internal CV score: 0.915828523415523
#
# Generation 93 - Current best internal CV score: 0.915828523415523
#
# Generation 94 - Current best internal CV score: 0.915828523415523
#
# Generation 95 - Current best internal CV score: 0.915828523415523
#
# Generation 96 - Current best internal CV score: 0.915828523415523
#
# 75.11 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: XGBClassifier(GradientBoostingClassifier(RFE(input_matrix, criterion=entropy, max_features=0.7000000000000001, n_estimators=100, step=0.8), learning_rate=0.01, max_depth=1, max_features=0.45, min_samples_leaf=7, min_samples_split=20, n_estimators=100, subsample=0.9500000000000001), learning_rate=0.001, max_depth=3, min_child_weight=9, n_estimators=100, n_jobs=1, subsample=1.0, verbosity=0)
#
# Weighted F1-score: 0.9502428505751781
#
# End of the TPOT system execution: 2023-01-08 03:12:27.307006

# %%
tpot_X2 = run_tpot(X2_train, y2_train, max_time_mins=60*5)

# Save the model
tpot_X2.export('tpot_models/tpot_X2.py')

# Save the model as pickle
with open("./tpot_model_X2.pickle", "wb") as f:
    pickle.dump({"template": tpot_X2.fitted_pipeline_, "_imputed": tpot_X2._imputed}, f)
# Out:
# Start TPOT:  2023-01-08 06:45:46.478619 Time Limit per Fold: 75min
# Estimated end: 2023-01-08 11:45:46.478619
#
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.907135120820044
#
# Generation 2 - Current best internal CV score: 0.9091425772274851
#
# Generation 3 - Current best internal CV score: 0.9097946147773127
#
# Generation 4 - Current best internal CV score: 0.9104188490197596
#
# Generation 5 - Current best internal CV score: 0.9104188490197596
#
# Generation 6 - Current best internal CV score: 0.9104188490197596
#
# Generation 7 - Current best internal CV score: 0.9128710651197952
#
# Generation 8 - Current best internal CV score: 0.9134810893977809
#
# Generation 9 - Current best internal CV score: 0.9134810893977809
#
# Generation 10 - Current best internal CV score: 0.9134810893977809
#
# Generation 11 - Current best internal CV score: 0.9134810893977809
#
# Generation 12 - Current best internal CV score: 0.9134810893977809
#
# Generation 13 - Current best internal CV score: 0.9134810893977809
#
# Generation 14 - Current best internal CV score: 0.9134810893977809
#
# Generation 15 - Current best internal CV score: 0.9134810893977809
#
# Generation 16 - Current best internal CV score: 0.9134810893977809
#
# Generation 17 - Current best internal CV score: 0.9134810893977809
#
# Generation 18 - Current best internal CV score: 0.9138470755168587
#
# Generation 19 - Current best internal CV score: 0.9150163346351107
#
# Generation 20 - Current best internal CV score: 0.9152178672279965
#
# Generation 21 - Current best internal CV score: 0.9152178672279965
#
# Generation 22 - Current best internal CV score: 0.9152178672279965
#
# Generation 23 - Current best internal CV score: 0.9152178672279965
#
# Generation 24 - Current best internal CV score: 0.9157618379850675
#
# Generation 25 - Current best internal CV score: 0.9157618379850675
#
# Generation 26 - Current best internal CV score: 0.9157618379850675
#
# Generation 27 - Current best internal CV score: 0.9157618379850675
#
# Generation 28 - Current best internal CV score: 0.9157618379850675
#
# Generation 29 - Current best internal CV score: 0.9157618379850675
#
# Generation 30 - Current best internal CV score: 0.9157618379850675
#
# Generation 31 - Current best internal CV score: 0.9157618379850675
#
# Generation 32 - Current best internal CV score: 0.9157618379850675
#
# Generation 33 - Current best internal CV score: 0.9158625799414395
#
# Generation 34 - Current best internal CV score: 0.917131950177675
#
# Generation 35 - Current best internal CV score: 0.917131950177675
#
# Generation 36 - Current best internal CV score: 0.917131950177675
#
# Generation 37 - Current best internal CV score: 0.917131950177675
#
# Generation 38 - Current best internal CV score: 0.9174514582532167
#
# Generation 39 - Current best internal CV score: 0.9174514582532167
#
# Generation 40 - Current best internal CV score: 0.9174514582532167
#
# Generation 41 - Current best internal CV score: 0.9174514582532167
#
# Generation 42 - Current best internal CV score: 0.9174514582532167
#
# Generation 43 - Current best internal CV score: 0.9174514582532167
#
# Generation 44 - Current best internal CV score: 0.9175105332882074
#
# Generation 45 - Current best internal CV score: 0.9175105332882074
#
# Generation 46 - Current best internal CV score: 0.9175105332882074
#
# Generation 47 - Current best internal CV score: 0.9175105332882074
#
# Generation 48 - Current best internal CV score: 0.9175105332882074
#
# Generation 49 - Current best internal CV score: 0.9175105332882074
#
# Generation 50 - Current best internal CV score: 0.9175105332882074
#
# Generation 51 - Current best internal CV score: 0.9175105332882074
#
# Generation 52 - Current best internal CV score: 0.9175105332882074
#
# Generation 53 - Current best internal CV score: 0.9175105332882074
#
# Generation 54 - Current best internal CV score: 0.9175105332882074
#
# Generation 55 - Current best internal CV score: 0.9175105332882074
#
# Generation 56 - Current best internal CV score: 0.9175105332882074
#
# Generation 57 - Current best internal CV score: 0.9175105332882074
#
# Generation 58 - Current best internal CV score: 0.9175105332882074
#
# Generation 59 - Current best internal CV score: 0.9175105332882074
#
# Generation 60 - Current best internal CV score: 0.9175105332882074
#
# Generation 61 - Current best internal CV score: 0.9175105332882074
#
# Generation 62 - Current best internal CV score: 0.9175105332882074
#
# Generation 63 - Current best internal CV score: 0.9175105332882074
#
# Generation 64 - Current best internal CV score: 0.9175105332882074
#
# Generation 65 - Current best internal CV score: 0.9175105332882074
#
# 75.02 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: ExtraTreesClassifier(RandomForestClassifier(input_matrix, bootstrap=True, criterion=gini, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=100), bootstrap=True, criterion=gini, max_features=0.8, min_samples_leaf=12, min_samples_split=14, n_estimators=100)
# Imputing missing values in feature set
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.9134043932669815
#
# Generation 2 - Current best internal CV score: 0.9134043932669815
#
# Generation 3 - Current best internal CV score: 0.9134043932669815
#
# Generation 4 - Current best internal CV score: 0.9134043932669815
#
# Generation 5 - Current best internal CV score: 0.9142960774535112
#
# Generation 6 - Current best internal CV score: 0.9142960774535112
#
# Generation 7 - Current best internal CV score: 0.9142960774535112
#
# Generation 8 - Current best internal CV score: 0.9155907608386855
#
# Generation 9 - Current best internal CV score: 0.9155907608386855
#
# Generation 10 - Current best internal CV score: 0.9155907608386855
#
# Generation 11 - Current best internal CV score: 0.9155907608386855
#
# Generation 12 - Current best internal CV score: 0.9155907608386855
#
# Generation 13 - Current best internal CV score: 0.9155907608386855
#
# Generation 14 - Current best internal CV score: 0.9155907608386855
#
# Generation 15 - Current best internal CV score: 0.9155907608386855
#
# Generation 16 - Current best internal CV score: 0.9155907608386855
#
# Generation 17 - Current best internal CV score: 0.9155907608386855
#
# Generation 18 - Current best internal CV score: 0.9155907608386855
#
# Generation 19 - Current best internal CV score: 0.9155907608386855
#
# Generation 20 - Current best internal CV score: 0.9155907608386855
#
# Generation 21 - Current best internal CV score: 0.9155907608386855
#
# 76.18 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: GradientBoostingClassifier(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), learning_rate=0.1, max_depth=3, max_features=0.4, min_samples_leaf=15, min_samples_split=16, n_estimators=100, subsample=1.0)
# Imputing missing values in feature set
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.9004745991384576
#
# Generation 2 - Current best internal CV score: 0.9047814501443394
#
# Generation 3 - Current best internal CV score: 0.9047814501443394
#
# Generation 4 - Current best internal CV score: 0.9065119077047115
#
# Generation 5 - Current best internal CV score: 0.9081037755729426
#
# Generation 6 - Current best internal CV score: 0.9081037755729426
#
# Generation 7 - Current best internal CV score: 0.9081037755729426
#
# Generation 8 - Current best internal CV score: 0.9081037755729426
#
# Generation 9 - Current best internal CV score: 0.9081037755729426
#
# Generation 10 - Current best internal CV score: 0.9081037755729426
#
# Generation 11 - Current best internal CV score: 0.9081037755729426
#
# Generation 12 - Current best internal CV score: 0.9081037755729426
#
# Generation 13 - Current best internal CV score: 0.9081037755729426
#
# Generation 14 - Current best internal CV score: 0.9091504372747646
#
# Generation 15 - Current best internal CV score: 0.9091504372747646
#
# Generation 16 - Current best internal CV score: 0.9091504372747646
#
# Generation 17 - Current best internal CV score: 0.9091504372747646
#
# Generation 18 - Current best internal CV score: 0.9091504372747646
#
# Generation 19 - Current best internal CV score: 0.9091504372747646
#
# Generation 20 - Current best internal CV score: 0.9091504372747646
#
# Generation 21 - Current best internal CV score: 0.9102022001460746
#
# Generation 22 - Current best internal CV score: 0.9102022001460746
#
# Generation 23 - Current best internal CV score: 0.9102022001460746
#
# Generation 24 - Current best internal CV score: 0.9105802344058956
#
# Generation 25 - Current best internal CV score: 0.9105802344058956
#
# Generation 26 - Current best internal CV score: 0.9105802344058956
#
# Generation 27 - Current best internal CV score: 0.9105802344058956
#
# Generation 28 - Current best internal CV score: 0.9105802344058956
#
# Generation 29 - Current best internal CV score: 0.9105802344058956
#
# Generation 30 - Current best internal CV score: 0.9105802344058956
#
# Generation 31 - Current best internal CV score: 0.9105802344058956
#
# Generation 32 - Current best internal CV score: 0.9105802344058956
#
# Generation 33 - Current best internal CV score: 0.9105802344058956
#
# Generation 34 - Current best internal CV score: 0.9105802344058956
#
# Generation 35 - Current best internal CV score: 0.9105802344058956
#
# Generation 36 - Current best internal CV score: 0.9105802344058956
#
# Generation 37 - Current best internal CV score: 0.9105802344058956
#
# Generation 38 - Current best internal CV score: 0.9105802344058956
#
# Generation 39 - Current best internal CV score: 0.9105802344058956
#
# Generation 40 - Current best internal CV score: 0.9105802344058956
#
# Generation 41 - Current best internal CV score: 0.9105802344058956
#
# Generation 42 - Current best internal CV score: 0.911051348799597
#
# Generation 43 - Current best internal CV score: 0.911051348799597
#
# Generation 44 - Current best internal CV score: 0.911051348799597
#
# Generation 45 - Current best internal CV score: 0.911051348799597
#
# Generation 46 - Current best internal CV score: 0.911051348799597
#
# Generation 47 - Current best internal CV score: 0.912282546288656
#
# Generation 48 - Current best internal CV score: 0.912282546288656
#
# Generation 49 - Current best internal CV score: 0.912282546288656
#
# Generation 50 - Current best internal CV score: 0.912282546288656
#
# Generation 51 - Current best internal CV score: 0.912282546288656
#
# 79.92 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: GradientBoostingClassifier(LogisticRegression(GaussianNB(input_matrix), C=0.1, dual=False, penalty=l2), learning_rate=0.1, max_depth=2, max_features=0.5, min_samples_leaf=15, min_samples_split=17, n_estimators=100, subsample=1.0)
# Imputing missing values in feature set
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.9096611709668194
#
# Generation 2 - Current best internal CV score: 0.909883036055577
#
# Generation 3 - Current best internal CV score: 0.909883036055577
#
# Generation 4 - Current best internal CV score: 0.9099873894308184
#
# Generation 5 - Current best internal CV score: 0.9099873894308184
#
# Generation 6 - Current best internal CV score: 0.9103023697803018
#
# Generation 7 - Current best internal CV score: 0.9124915145308075
#
# Generation 8 - Current best internal CV score: 0.9124915145308075
#
# Generation 9 - Current best internal CV score: 0.9124915145308075
#
# Generation 10 - Current best internal CV score: 0.9124915145308075
#
# Generation 11 - Current best internal CV score: 0.9129171999094616
#
# Generation 12 - Current best internal CV score: 0.9129171999094616
#
# Generation 13 - Current best internal CV score: 0.9129171999094616
#
# Generation 14 - Current best internal CV score: 0.9129171999094616
#
# Generation 15 - Current best internal CV score: 0.913489938277762
#
# Generation 16 - Current best internal CV score: 0.913489938277762
#
# Generation 17 - Current best internal CV score: 0.913489938277762
#
# Generation 18 - Current best internal CV score: 0.913489938277762
#
# Generation 19 - Current best internal CV score: 0.913489938277762
#
# Generation 20 - Current best internal CV score: 0.9139890630995439
#
# Generation 21 - Current best internal CV score: 0.9139890630995439
#
# Generation 22 - Current best internal CV score: 0.9139890630995439
#
# Generation 23 - Current best internal CV score: 0.9139890630995439
#
# Generation 24 - Current best internal CV score: 0.9139890630995439
#
# Generation 25 - Current best internal CV score: 0.9139890630995439
#
# Generation 26 - Current best internal CV score: 0.9139890630995439
#
# Generation 27 - Current best internal CV score: 0.9139890630995439
#
# Generation 28 - Current best internal CV score: 0.9139890630995439
#
# Generation 29 - Current best internal CV score: 0.9139890630995439
#
# Generation 30 - Current best internal CV score: 0.9139890630995439
#
# Generation 31 - Current best internal CV score: 0.9139890630995439
#
# Generation 32 - Current best internal CV score: 0.9139890630995439
#
# Generation 33 - Current best internal CV score: 0.9139890630995439
#
# Generation 34 - Current best internal CV score: 0.9139890630995439
#
# Generation 35 - Current best internal CV score: 0.9139890630995439
#
# Generation 36 - Current best internal CV score: 0.9139890630995439
#
# Generation 37 - Current best internal CV score: 0.9139890630995439
#
# Generation 38 - Current best internal CV score: 0.9139890630995439
#
# Generation 39 - Current best internal CV score: 0.9141220482881474
#
# Generation 40 - Current best internal CV score: 0.9141220482881474
#
# Generation 41 - Current best internal CV score: 0.9141220482881474
#
# Generation 42 - Current best internal CV score: 0.9141220482881474
#
# Generation 43 - Current best internal CV score: 0.9141220482881474
#
# Generation 44 - Current best internal CV score: 0.9141220482881474
#
# Generation 45 - Current best internal CV score: 0.9141220482881474
#
# Generation 46 - Current best internal CV score: 0.9141220482881474
#
# Generation 47 - Current best internal CV score: 0.9141220482881474
#
# Generation 48 - Current best internal CV score: 0.9141220482881474
#
# Generation 49 - Current best internal CV score: 0.9141220482881474
#
# Generation 50 - Current best internal CV score: 0.9141220482881474
#
# Generation 51 - Current best internal CV score: 0.9141220482881474
#
# Generation 52 - Current best internal CV score: 0.9141220482881474
#
# Generation 53 - Current best internal CV score: 0.9141220482881474
#
# Generation 54 - Current best internal CV score: 0.9141220482881474
#
# Generation 55 - Current best internal CV score: 0.9141220482881474
#
# Generation 56 - Current best internal CV score: 0.9141220482881474
#
# Generation 57 - Current best internal CV score: 0.9141220482881474
#
# Generation 58 - Current best internal CV score: 0.9141220482881474
#
# Generation 59 - Current best internal CV score: 0.9141220482881474
#
# Generation 60 - Current best internal CV score: 0.9141220482881474
#
# Generation 61 - Current best internal CV score: 0.9141220482881474
#
# Generation 62 - Current best internal CV score: 0.9141220482881474
#
# Generation 63 - Current best internal CV score: 0.9141220482881474
#
# Generation 64 - Current best internal CV score: 0.9141220482881474
#
# Generation 65 - Current best internal CV score: 0.9141220482881474
#
# Generation 66 - Current best internal CV score: 0.9141220482881474
#
# Generation 67 - Current best internal CV score: 0.9141220482881474
#
# Generation 68 - Current best internal CV score: 0.9141220482881474
#
# Generation 69 - Current best internal CV score: 0.9141220482881474
#
# Generation 70 - Current best internal CV score: 0.9141220482881474
#
# Generation 71 - Current best internal CV score: 0.9141220482881474
#
# Generation 72 - Current best internal CV score: 0.9141220482881474
#
# Generation 73 - Current best internal CV score: 0.9141220482881474
#
# Generation 74 - Current best internal CV score: 0.9141220482881474
#
# Generation 75 - Current best internal CV score: 0.9141220482881474
#
# Generation 76 - Current best internal CV score: 0.9141220482881474
#
# Generation 77 - Current best internal CV score: 0.9141220482881474
#
# Generation 78 - Current best internal CV score: 0.9141220482881474
#
# Generation 79 - Current best internal CV score: 0.9141220482881474
#
# Generation 80 - Current best internal CV score: 0.9141220482881474
#
# Generation 81 - Current best internal CV score: 0.9141220482881474
#
# Generation 82 - Current best internal CV score: 0.9141220482881474
#
# Generation 83 - Current best internal CV score: 0.9141220482881474
#
# Generation 84 - Current best internal CV score: 0.9141220482881474
#
# Generation 85 - Current best internal CV score: 0.9141220482881474
#
# Generation 86 - Current best internal CV score: 0.9141220482881474
#
# Generation 87 - Current best internal CV score: 0.9141220482881474
#
# Generation 88 - Current best internal CV score: 0.9141220482881474
#
# Generation 89 - Current best internal CV score: 0.9141220482881474
#
# Generation 90 - Current best internal CV score: 0.9141220482881474
#
# Generation 91 - Current best internal CV score: 0.9141220482881474
#
# Generation 92 - Current best internal CV score: 0.9141220482881474
#
# Generation 93 - Current best internal CV score: 0.9141220482881474
#
# Generation 94 - Current best internal CV score: 0.9141220482881474
#
# Generation 95 - Current best internal CV score: 0.9141220482881474
#
# Generation 96 - Current best internal CV score: 0.9141220482881474
#
# Generation 97 - Current best internal CV score: 0.9141220482881474
#
# Generation 98 - Current best internal CV score: 0.9141220482881474
#
# Generation 99 - Current best internal CV score: 0.9141220482881474
#
# Generation 100 - Current best internal CV score: 0.9141220482881474
#
# Best pipeline: GradientBoostingClassifier(LinearSVC(input_matrix, C=0.1, dual=False, loss=squared_hinge, penalty=l1, tol=1e-05), learning_rate=0.1, max_depth=2, max_features=0.15000000000000002, min_samples_leaf=14, min_samples_split=20, n_estimators=100, subsample=0.8)
#
# Weighted F1-score: 0.9472151569117381
#
# End of the TPOT system execution: 2023-01-08 11:43:48.363807

# %% [markdown]
# ## Performance of the best `X1` pipeline
# The below-code is in the `tpot_models/tpot_X1.py` file.

# %%
# Import tpots
import numpy as np
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, make_union
from tpot.builtins import StackingEstimator
from xgboost import XGBClassifier
from sklearn.impute import SimpleImputer
from tpot.export_utils import set_param_recursive

training_features, testing_features, training_target, testing_target = \
            train_test_split(X1, target, random_state=42)

imputer = SimpleImputer(strategy="median")
imputer.fit(training_features)
training_features = imputer.transform(training_features)
testing_features = imputer.transform(testing_features)

# Average CV score on the training set was: 0.915828523415523
exported_pipeline = make_pipeline(
    RFE(estimator=ExtraTreesClassifier(criterion="entropy", max_features=0.7000000000000001, n_estimators=100), step=0.8),
    StackingEstimator(estimator=GradientBoostingClassifier(learning_rate=0.01, max_depth=1, max_features=0.45, min_samples_leaf=7, min_samples_split=20, n_estimators=100, subsample=0.9500000000000001)),
    XGBClassifier(learning_rate=0.001, max_depth=3, min_child_weight=9, n_estimators=100, n_jobs=1, subsample=1.0, verbosity=0)
)
# Fix random state for all the steps in exported pipeline
set_param_recursive(exported_pipeline.steps, 'random_state', 42)

exported_pipeline.fit(training_features, training_target)
results_X1 = exported_pipeline.predict(testing_features)

# Compute the classification metrics
classification_metrics(testing_target, results_X1)
# Out:
# Accuracy: 0.9352451433857539
# Precision (weighted): 0.921187543781003
# Recall (weighted): 0.9352451433857539
# F1-score (weighted): 0.9115738139776588
# ROC-AUC (weighted): 0.5458077243082208

# %%
# Predict based on best models and present the metrics
import numpy as np
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, make_union
from sklearn.svm import LinearSVC
from tpot.builtins import StackingEstimator
from sklearn.impute import SimpleImputer
from tpot.export_utils import set_param_recursive

# NOTE: Make sure that the outcome column is labeled 'target' in the data file
training_features, testing_features, training_target, testing_target = \
            train_test_split(X2, target, random_state=42)

imputer = SimpleImputer(strategy="median")
imputer.fit(training_features)
training_features = imputer.transform(training_features)
testing_features = imputer.transform(testing_features)

# Average CV score on the training set was: 0.9141220482881474
exported_pipeline = make_pipeline(
    StackingEstimator(estimator=LinearSVC(C=0.1, dual=False, loss="squared_hinge", penalty="l1", tol=1e-05)),
    GradientBoostingClassifier(learning_rate=0.1, max_depth=2, max_features=0.15000000000000002, min_samples_leaf=14, min_samples_split=20, n_estimators=100, subsample=0.8)
)
# Fix random state for all the steps in exported pipeline
set_param_recursive(exported_pipeline.steps, 'random_state', 42)

exported_pipeline.fit(training_features, training_target)
results_X2 = exported_pipeline.predict(testing_features)

# Compute the classification metrics
classification_metrics(testing_target, results_X2)
# Out:
# Accuracy: 0.9333950046253469
# Precision (weighted): 0.9130920826233779
# Recall (weighted): 0.9333950046253469
# F1-score (weighted): 0.9103808104871207
# ROC-AUC (weighted): 0.5448146756488366
