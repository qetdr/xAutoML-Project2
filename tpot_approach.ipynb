# %% [markdown]
# # Assignment
# This project aims to use AutoML to predict clinical outcomes using imaging and clinical variables. The imaging modality of interest is positron emission tomography (PET). We provide a data dictionary sheet that has an explanation for what each variable resembles.
#
# The outcome of interest to predict is MACE with heart failure (`o_mace` column). Variables to include in the model are highlighted in <font color='gold'>yellow </font>. (This includes the bare minimum of variables, avoiding known collinearity). Variables highlighted in <font color = 'blue'>blue</font> are variables that are known to be collinear, with some of the yellow-highlighted ones.
#
# As a **second step**, if you can please build another predictive model **using BOTH the <font color = 'gold'>yellow</font> and the <font color = 'blue'>blue</font> highlighted variables**, just to assess if some of the collinear variables may be more predictive than others. (This model will have a large number of variables in the model).
#
# Variables **not to be used** for building the model (may be used at a later point) are highlighted in <font color = 'grey'>grey</font>.
#
# One thing to note is the unindexed values for `lvmass`, `EF`, and `systolic/diastolic` volumes but not the indexed ones (indexed ones end with `_ind`). This is to avoid collinearity, too, so only include the indexed ones with the rest of the variables in the model for model 2 but not model 1.
#
# Once the model is built, we need to explain the outcome based on different groups of interest (i.e, different age groups, different race/ethnicity groups ). For interpretability, we can explore different options; LIME, SHAP,..etc.

# %% [markdown]
# # Setup

# %%
# Install the packages defined in `requirements.txt`
# !pip install -r requirements.txt

# %%
# Working with data frames
import pandas as pd
import numpy as np
import sklearn.datasets

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from tpot import TPOTClassifier

# Misc
import pickle
import datetime
import warnings
#from google.colab.output import eval_js
#eval_js('google.colab.output.setIframeHeight("500")') # output cell size in GC
warnings.filterwarnings('ignore') # disable warnings
# Out:
# C:\Users\burno\AppData\Local\Programs\Python\Python38\lib\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %% [markdown]
# # Data Import
# Because the data are confidential, we are not allowed to include it in the repository. Hence, we import it from a local machine outside of the working directory (the present repository).
#
# Of note, we mport two sheets from the Excel workbook: the data and the legend (data dictionary) sheets. The latter is used for, e.g., excluding the <font color='grey'> grey </font> features, as well as building models without and with <font color='blue'> blue </font> features.

# %%
df_raw = pd.read_excel('df_project2.xlsx', sheet_name = 'complete_db') # read the df from outside the directory 
df_legend = pd.read_excel('df_project2.xlsx', sheet_name = 'data_dictionary') # read the data dictionary

df_legend.head()
# Out:
#    position          name_col              name   type  isnumeric  format  \
# 0         1  annon_serial_num  annon_serial_num  float          1   %9.0g
# 1         2            sd_age            sd_age   byte          1  %10.0g
# 2         3            sd_sex            sd_sex   str6          0     %9s
# 3         4   sd_race_unified   sd_race_unified  str38          0    %38s
# 4         5   sd_ethn_unified   sd_ethn_unified  str12          0    %12s
#
#   vallab              varlab         Explanation column_color  no_yes_vars
# 0    NaN  group(id pet_date)                 NaN       yellow          0.0
# 1    NaN              sd_age         patient age       yellow          0.0
# 2    NaN              sd_sex      patient gender       yellow          0.0
# 3    NaN     sd_race_unified        patient race       yellow          0.0
# 4    NaN     sd_ethn_unified  patient ethinicity         blue          0.0

# %% [markdown]
# ## Basic Data Preprocessing

# %%
# remove non-_ind columns
print(f"df_raw dimensions before removing non-'_ind' cols:{df_raw.shape} ")
# Find columns that end with '_ind'
ind_cols = df_raw.columns[df_raw.columns.str.endswith('_ind')]
# Find column names that have both 'raw' and 'index' column
colnames_non_ind = ind_cols.str.replace('_ind', '')

# Remove the non-_ind columns
remove_yellows = []
for col in colnames_non_ind:
  all_cols = df_raw.columns[df_raw.columns.str.startswith(col)]
  for col2 in all_cols:
    if '_ind' in col2:
      pass
    else:
      remove_yellows.append(col2)
      df_raw = df_raw.drop(columns = [col2])
print(f"df_raw dimensions after removing non-'_ind' cols:{df_raw.shape} ")

# Find the column names based on color
grey_cols = df_legend[df_legend['column_color'] == 'grey']['name_col']
blue_cols = df_legend[df_legend['column_color'] == 'blue']['name_col']
yellow_cols = df_legend[df_legend['column_color'] == 'yellow']['name_col']
# Remove the non-_ind cols
yellow_cols = yellow_cols[~yellow_cols.isin(remove_yellows)].reset_index(drop = True)
green_cols = df_legend[df_legend['column_color'] == 'green']['name_col']


# Find the binary No/Yes vars (to be replaced with 0/1)
yes_no_cols = df_legend[df_legend['no_yes_vars'] == 1]['name_col'].values
df_raw[yes_no_cols] = df_raw[yes_no_cols].replace(to_replace=['No', 
                                                              'Yes'], 
                                                  value=[0, 1]) # replace No-Yes to 0-1

# Binarize 'sex' variable
df_raw['sd_sex'] = df_raw['sd_sex'].replace(to_replace=['Male', 
                                                        'Female'], 
                                            value=[0, 1])

# Binarize 'pharm_stressor'
df_raw['pharm_stressor'] = df_raw['pharm_stressor'].replace(to_replace=['Adenosine', 
                                                                        'Regadenoson'], 
                                                            value=[0, 1])

# Convert 'sd_bmi_cat' and 'cac_cat' to ordered numeric variable
df_raw['sd_bmi_cat'] = df_raw['sd_bmi_cat'].replace(to_replace = ['Underweight (<18.5kg/m2)',
                                           'Normal (18.5-25kg/m2)',
                                           'Overweight (25-30kg/m2)',
                                           'Obese (≥30kg/m2)'
                                           ],
                             value = [1,2,3,4])

df_raw['cac_cat'] = df_raw['cac_cat'].replace(to_replace = ['CACS 0', 
                                        'CACS 1-99','CACS 100-399',
                                        'CACS 400-999', 'CACS ≥1000'],
                          value = [0,1,2,3,4])
# Out:
# df_raw dimensions before removing non-'_ind' cols:(4323, 109)
# df_raw dimensions after removing non-'_ind' cols:(4323, 105)

# %% [markdown]
# ## Dataset Extraction

# %%
# Extract the target
target = df_raw[green_cols]['o_mace']

# Create the yellow X features df (X1)
X1 = df_raw[yellow_cols]

# Create the yellow-blue X features df (X2)
X2 = df_raw.drop(columns = grey_cols.append(green_cols))

# Drop the ID-col (it's sequential and can be easily retrieved)
X1 = X1.drop(columns = 'annon_serial_num')
X2 = X2.drop(columns = 'annon_serial_num')

# Convert `object` vars to dummies (TPOT might not deal well with cat-vars)
X1 = pd.get_dummies(X1, drop_first = True)
X2 = pd.get_dummies(X2, drop_first = True)


# Print the dimensions
print(f'Initial df dimensions: {df_raw.shape}')
print(f'Yellow X df dimensions: {X1.shape}')
print(f'Yellow-blue X df dimensions: {X2.shape}')
print(f'target dimensions: {target.shape}')
# Out:
# Initial df dimensions: (4323, 105)
# Yellow X df dimensions: (4323, 60)
# Yellow-blue X df dimensions: (4323, 84)
# target dimensions: (4323,)

# %%
# saving data for interpretability task
#X1.to_csv('X1.csv', index=False)
#X2.to_csv('X2.csv', index=False)
#target.to_csv('target.csv', index=False)

# %% [markdown]
# ## Check for missing values and other data characteristics

# %%
print('Number of missing values:')
print()
print(f'Target y: {target.isnull().sum()}')
#print(f'Target X1: {X1.isnull().sum()}')
#print(f'Target X2: {X2.isnull().sum()}')
# Out:
# Number of missing values:
#
# Target y: 0

# %% [markdown]
# # Train-test split

# %%
# Train-test split for yellow X
X1_train, X1_val, y1_train, y1_val = train_test_split(X1, target, test_size=0.1, random_state=42)

# Train-test split for yellow-blue X
X2_train, X2_val, y2_train, y2_val = train_test_split(X2, target, test_size=0.1, random_state=42)

# %%
#models to pickle
X1_train.to_pickle("./X1_train.pkl")
y1_train.to_pickle("./y1_train.pkl")
X2_train.to_pickle("./X2_train.pkl")
y2_train.to_pickle("./y2_train.pkl")
X1_val.to_pickle("./X1_val.pkl")
y1_val.to_pickle("./y1_val.pkl")
X2_val.to_pickle("./X2_val.pkl")
y2_val.to_pickle("./y2_val.pkl")

# %% [markdown]
# # TPOT
# - Maybe also see this tutorial: https://medium.com/analytics-vidhya/learn-to-use-tpot-an-automl-tool-4c52148c2bc9
# - A paper using TPOT for medical classification: https://academic.oup.com/bioinformatics/article/36/6/1772/5614811
# - More about `TPOTClassifier` class args: http://epistasislab.github.io/tpot/using/
# - TPOT Github repo: https://github.com/EpistasisLab/tpot

# %% [markdown]
# # 1st `tpot` run

# %%
def build_tpot(X_train, y_train, max_time_mins = None):

  # Initialize the TPOT framework for classification.
  tpot = TPOTClassifier(
    generations=100, # Number of iterations to run the pipeline optimization process.
    population_size=20, # Number of individuals to retain in the GP population every generation. 
    scoring = 'f1_weighted', # use the wieghted F1 score
    cv = 5,
    n_jobs = -2, # all CPUs but one are used.
    max_time_mins = max_time_mins,
    max_eval_time_mins = 5,
    random_state = 42,
    verbosity = 2
  )

  # Fit the framework.
  tpot.fit(X_train, y_train)

  return tpot


def run_tpot(X, y, max_time_mins, n_splits=3):

  # Limit time to be equally between all fold and
  # also the final run on the entire dataset.
  time_limit = max(1, max_time_mins // (n_splits + 1))

  # Informative runtime information.
  start_run = datetime.datetime.now()
  estimated_end = start_run + datetime.timedelta(minutes=time_limit*(n_splits + 1))
  print(f'Start TPOT:  {start_run} Time Limit per Fold: {time_limit}min')
  print(f'Estimated end: {estimated_end}\n')

  skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
  scores = []

  # Perform startified cross validation.s
  for train_index, val_index in skf.split(X, y):

    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    tpot = build_tpot(X_train, y_train, time_limit)

    # Predictions and weighted F1-score.
    y_pred = tpot.predict(X_val)
    score = f1_score(y_pred, y_val, average='weighted')
    scores.append(score)

  # Building the final TPOT model on all samples.
  tpot = build_tpot(X, y, time_limit)
  avg_score = sum(scores) / len(scores)

  print()
  print(f'Weighted F1-score: {avg_score}\n')
  print(f'End of the TPOT system execution: {datetime.datetime.now()}\n')

  return tpot

# %%
tpot_X1 = run_tpot(X1_train, y1_train, max_time_mins=60*5)

# Save the model
tpot_X1.export('tpot_models/tpot_X1.py')

# Save the model as pickle
with open("./tpot_model_X1.pickle", "wb") as f:
    pickle.dump({"template": tpot_X1.fitted_pipeline_, "_imputed": tpot._imputed}, f)
# Out:
# Start TPOT:  2023-01-03 14:13:50.574965 Time Limit per Fold: 75min
# Estimated end: 2023-01-03 19:13:50.574965
#
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.9048399014158349
#
# Generation 2 - Current best internal CV score: 0.9048399014158349
#
# Generation 3 - Current best internal CV score: 0.9057707282764536
#
# Generation 4 - Current best internal CV score: 0.9058521849826461
#
# Generation 5 - Current best internal CV score: 0.9058521849826461
#
# Generation 6 - Current best internal CV score: 0.9060191968779951
#
# Generation 7 - Current best internal CV score: 0.9060191968779951
#
# Generation 8 - Current best internal CV score: 0.9066792560973738
#
# Generation 9 - Current best internal CV score: 0.9066792560973738
#
# Generation 10 - Current best internal CV score: 0.9066792560973738
#
# Generation 11 - Current best internal CV score: 0.9089390869798326
#
# Generation 12 - Current best internal CV score: 0.9092220904815151
#
# Generation 13 - Current best internal CV score: 0.9092220904815151
#
# Generation 14 - Current best internal CV score: 0.9119647681070419
#
# Generation 15 - Current best internal CV score: 0.9119647681070419
#
# Generation 16 - Current best internal CV score: 0.9119647681070419
#
# Generation 17 - Current best internal CV score: 0.9119647681070419
#
# Generation 18 - Current best internal CV score: 0.9119647681070419
#
# Generation 19 - Current best internal CV score: 0.9128383326259577
#
# Generation 20 - Current best internal CV score: 0.9128383326259577
#
# Generation 21 - Current best internal CV score: 0.9128383326259577
#
# Generation 22 - Current best internal CV score: 0.9128383326259577
#
# Generation 23 - Current best internal CV score: 0.9128383326259577
#
# Generation 24 - Current best internal CV score: 0.9128383326259577
#
# Generation 25 - Current best internal CV score: 0.9128383326259577
#
# Generation 26 - Current best internal CV score: 0.9128383326259577
#
# Generation 27 - Current best internal CV score: 0.9128383326259577
#
# Generation 28 - Current best internal CV score: 0.9128383326259577
#
# Generation 29 - Current best internal CV score: 0.9128383326259577
#
# 75.08 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: RandomForestClassifier(RandomForestClassifier(SelectPercentile(CombineDFs(PolynomialFeatures(MinMaxScaler(input_matrix), degree=2, include_bias=False, interaction_only=False), input_matrix), percentile=77), bootstrap=False, criterion=gini, max_features=0.05, min_samples_leaf=11, min_samples_split=6, n_estimators=100), bootstrap=True, criterion=gini, max_features=0.2, min_samples_leaf=11, min_samples_split=4, n_estimators=100)
# Imputing missing values in feature set
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.906155800126742
#
# Generation 2 - Current best internal CV score: 0.9069649966562479
#
# Generation 3 - Current best internal CV score: 0.9069649966562479
#
# Generation 4 - Current best internal CV score: 0.9089856736826677
#
# Generation 5 - Current best internal CV score: 0.9089856736826677
#
# Generation 6 - Current best internal CV score: 0.9105873916254383
#
# Generation 7 - Current best internal CV score: 0.9105873916254383
#
# Generation 8 - Current best internal CV score: 0.9105873916254383
#
# Generation 9 - Current best internal CV score: 0.9105873916254383
#
# Generation 10 - Current best internal CV score: 0.910873533973146
#
# Generation 11 - Current best internal CV score: 0.9123923803696392
#
# Generation 12 - Current best internal CV score: 0.9123923803696392
#
# Generation 13 - Current best internal CV score: 0.9123923803696392
#
# Generation 14 - Current best internal CV score: 0.9123923803696392
#
# Generation 15 - Current best internal CV score: 0.9123923803696392
#
# Generation 16 - Current best internal CV score: 0.9123923803696392
#
# Generation 17 - Current best internal CV score: 0.9123923803696392
#
# Generation 18 - Current best internal CV score: 0.9123923803696392
#
# Generation 19 - Current best internal CV score: 0.9134862607279814
#
# Generation 20 - Current best internal CV score: 0.9134862607279814
#
# Generation 21 - Current best internal CV score: 0.9134862607279814
#
# Generation 22 - Current best internal CV score: 0.9134862607279814
#
# Generation 23 - Current best internal CV score: 0.9134862607279814
#
# Generation 24 - Current best internal CV score: 0.9134862607279814
#
# Generation 25 - Current best internal CV score: 0.9134862607279814
#
# Generation 26 - Current best internal CV score: 0.9134862607279814
#
# Generation 27 - Current best internal CV score: 0.9134862607279814
#
# Generation 28 - Current best internal CV score: 0.9134862607279814
#
# Generation 29 - Current best internal CV score: 0.9145291865001857
#
# Generation 30 - Current best internal CV score: 0.9145291865001857
#
# Generation 31 - Current best internal CV score: 0.9145291865001857
#
# Generation 32 - Current best internal CV score: 0.9145291865001857
#
# Generation 33 - Current best internal CV score: 0.9154309105908942
#
# Generation 34 - Current best internal CV score: 0.9154309105908942
#
# Generation 35 - Current best internal CV score: 0.9154309105908942
#
# Generation 36 - Current best internal CV score: 0.9154309105908942
#
# Generation 37 - Current best internal CV score: 0.9154309105908942
#
# Generation 38 - Current best internal CV score: 0.9154309105908942
#
# Generation 39 - Current best internal CV score: 0.9154309105908942
#
# 75.02 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: ExtraTreesClassifier(RandomForestClassifier(LinearSVC(input_matrix, C=0.5, dual=False, loss=squared_hinge, penalty=l2, tol=0.01), bootstrap=True, criterion=gini, max_features=0.45, min_samples_leaf=19, min_samples_split=4, n_estimators=100), bootstrap=True, criterion=gini, max_features=0.6000000000000001, min_samples_leaf=11, min_samples_split=11, n_estimators=100)
# Imputing missing values in feature set
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.9131381336453295
#
# Generation 2 - Current best internal CV score: 0.9131381336453295
#
# Generation 3 - Current best internal CV score: 0.9131381336453295
#
# Generation 4 - Current best internal CV score: 0.9131381336453295
#
# Generation 5 - Current best internal CV score: 0.9131381336453295
#
# Generation 6 - Current best internal CV score: 0.9131381336453295
#
# Generation 7 - Current best internal CV score: 0.9131381336453295
#
# Generation 8 - Current best internal CV score: 0.9131381336453295
#
# Generation 9 - Current best internal CV score: 0.9131381336453295
#
# Generation 10 - Current best internal CV score: 0.9132520386657876
#
# Generation 11 - Current best internal CV score: 0.9132520386657876
#
# Generation 12 - Current best internal CV score: 0.9134917072628055
#
# Generation 13 - Current best internal CV score: 0.9134917072628055
#
# Generation 14 - Current best internal CV score: 0.9152971318665424
#
# Generation 15 - Current best internal CV score: 0.9152971318665424
#
# Generation 16 - Current best internal CV score: 0.9152971318665424
#
# Generation 17 - Current best internal CV score: 0.9152971318665424
#
# Generation 18 - Current best internal CV score: 0.9152971318665424
#
# Generation 19 - Current best internal CV score: 0.9152971318665424
#
# Generation 20 - Current best internal CV score: 0.9152971318665424
#
# Generation 21 - Current best internal CV score: 0.9159436095002309
#
# Generation 22 - Current best internal CV score: 0.9159436095002309
#
# Generation 23 - Current best internal CV score: 0.9162326595987291
#
# Generation 24 - Current best internal CV score: 0.9162326595987291
#
# Generation 25 - Current best internal CV score: 0.9162326595987291
#
# Generation 26 - Current best internal CV score: 0.9162326595987291
#
# Generation 27 - Current best internal CV score: 0.9165232050300591
#
# Generation 28 - Current best internal CV score: 0.9165232050300591
#
# Generation 29 - Current best internal CV score: 0.916635172759281
#
# Generation 30 - Current best internal CV score: 0.916635172759281
#
# Generation 31 - Current best internal CV score: 0.916635172759281
#
# Generation 32 - Current best internal CV score: 0.916635172759281
#
# Generation 33 - Current best internal CV score: 0.916635172759281
#
# Generation 34 - Current best internal CV score: 0.916635172759281
#
# Generation 35 - Current best internal CV score: 0.916635172759281
#
# Generation 36 - Current best internal CV score: 0.916635172759281
#
# Generation 37 - Current best internal CV score: 0.916635172759281
#
# Generation 38 - Current best internal CV score: 0.916635172759281
#
# Generation 39 - Current best internal CV score: 0.9171180691895545
#
# Generation 40 - Current best internal CV score: 0.9171180691895545
#
# Generation 41 - Current best internal CV score: 0.9171180691895545
#
# Generation 42 - Current best internal CV score: 0.9171180691895545
#
# Generation 43 - Current best internal CV score: 0.9171180691895545
#
# Generation 44 - Current best internal CV score: 0.9171180691895545
#
# Generation 45 - Current best internal CV score: 0.9171180691895545
#
# Generation 46 - Current best internal CV score: 0.9171180691895545
#
# Generation 47 - Current best internal CV score: 0.9171180691895545
#
# Generation 48 - Current best internal CV score: 0.9171938935717865
#
# Generation 49 - Current best internal CV score: 0.9171938935717865
#
# Generation 50 - Current best internal CV score: 0.9171938935717865
#
# Generation 51 - Current best internal CV score: 0.9180225626809821
#
# Generation 52 - Current best internal CV score: 0.9180225626809821
#
# Generation 53 - Current best internal CV score: 0.9180225626809821
#
# Generation 54 - Current best internal CV score: 0.9180225626809821
#
# Generation 55 - Current best internal CV score: 0.9180225626809821
#
# Generation 56 - Current best internal CV score: 0.9180225626809821
#
# Generation 57 - Current best internal CV score: 0.9196438286537078
#
# Generation 58 - Current best internal CV score: 0.9196438286537078
#
# Generation 59 - Current best internal CV score: 0.9196438286537078
#
# Generation 60 - Current best internal CV score: 0.9196438286537078
#
# Generation 61 - Current best internal CV score: 0.9196438286537078
#
# Generation 62 - Current best internal CV score: 0.9196438286537078
#
# Generation 63 - Current best internal CV score: 0.9196438286537078
#
# Generation 64 - Current best internal CV score: 0.9196438286537078
#
# Generation 65 - Current best internal CV score: 0.9196438286537078
#
# Generation 66 - Current best internal CV score: 0.9196438286537078
#
# Generation 67 - Current best internal CV score: 0.9196438286537078
#
# Generation 68 - Current best internal CV score: 0.9196438286537078
#
# Generation 69 - Current best internal CV score: 0.9196438286537078
#
# Generation 70 - Current best internal CV score: 0.9196438286537078
#
# Generation 71 - Current best internal CV score: 0.9196438286537078
#
# Generation 72 - Current best internal CV score: 0.9196438286537078
#
# Generation 73 - Current best internal CV score: 0.9196438286537078
#
# Generation 74 - Current best internal CV score: 0.9196438286537078
#
# Generation 75 - Current best internal CV score: 0.9196438286537078
#
# Generation 76 - Current best internal CV score: 0.9196438286537078
#
# Generation 77 - Current best internal CV score: 0.9196438286537078
#
# Generation 78 - Current best internal CV score: 0.9196438286537078
#
# Generation 79 - Current best internal CV score: 0.9196438286537078
#
# Generation 80 - Current best internal CV score: 0.9196438286537078
#
# Generation 81 - Current best internal CV score: 0.9196438286537078
#
# Generation 82 - Current best internal CV score: 0.9196438286537078
#
# Generation 83 - Current best internal CV score: 0.9196438286537078
#
# Generation 84 - Current best internal CV score: 0.9196438286537078
#
# Generation 85 - Current best internal CV score: 0.9196438286537078
#
# Generation 86 - Current best internal CV score: 0.9196438286537078
#
# Generation 87 - Current best internal CV score: 0.9196438286537078
#
# Generation 88 - Current best internal CV score: 0.9196438286537078
#
# Generation 89 - Current best internal CV score: 0.9196438286537078
#
# Generation 90 - Current best internal CV score: 0.9196438286537078
#
# Generation 91 - Current best internal CV score: 0.9196438286537078
#
# Generation 92 - Current best internal CV score: 0.9196438286537078
#
# Generation 93 - Current best internal CV score: 0.9196438286537078
#
# Generation 94 - Current best internal CV score: 0.9196438286537078
#
# Generation 95 - Current best internal CV score: 0.9196438286537078
#
# Generation 96 - Current best internal CV score: 0.9196438286537078
#
# Generation 97 - Current best internal CV score: 0.9196438286537078
#
# Generation 98 - Current best internal CV score: 0.9196438286537078
#
# Generation 99 - Current best internal CV score: 0.9196438286537078
#
# 75.20 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: GradientBoostingClassifier(MLPClassifier(input_matrix, alpha=0.001, learning_rate_init=0.5), learning_rate=0.1, max_depth=4, max_features=0.45, min_samples_leaf=9, min_samples_split=3, n_estimators=100, subsample=0.45)
# Imputing missing values in feature set
# Imputing missing values in feature set
#
# Generation 1 - Current best internal CV score: 0.9087489211291209
#
# Generation 2 - Current best internal CV score: 0.9087489211291209
#
# Generation 3 - Current best internal CV score: 0.9097796670121738
#
# Generation 4 - Current best internal CV score: 0.910020758857151
#
# Generation 5 - Current best internal CV score: 0.9104150534558775
#
# Generation 6 - Current best internal CV score: 0.9104150534558775
#
# Generation 7 - Current best internal CV score: 0.9113289909495255
#
# Generation 8 - Current best internal CV score: 0.9113289909495255
#
# Generation 9 - Current best internal CV score: 0.9113289909495255
#
# Generation 10 - Current best internal CV score: 0.9130189356361506
#
# Generation 11 - Current best internal CV score: 0.9130189356361506
#
# Generation 12 - Current best internal CV score: 0.9130189356361506
#
# Generation 13 - Current best internal CV score: 0.9130189356361506
#
# Generation 14 - Current best internal CV score: 0.9130189356361506
#
# Generation 15 - Current best internal CV score: 0.9130189356361506
#
# Generation 16 - Current best internal CV score: 0.9133771748613315
#
# Generation 17 - Current best internal CV score: 0.9135597032290743
#
# Generation 18 - Current best internal CV score: 0.9142208714315124
#
# Generation 19 - Current best internal CV score: 0.9142208714315124
#
# Generation 20 - Current best internal CV score: 0.9142208714315124
#
# Generation 21 - Current best internal CV score: 0.9142208714315124
#
# Generation 22 - Current best internal CV score: 0.9142208714315124
#
# Generation 23 - Current best internal CV score: 0.9142208714315124
#
# Generation 24 - Current best internal CV score: 0.9142208714315124
#
# Generation 25 - Current best internal CV score: 0.9142208714315124
#
# Generation 26 - Current best internal CV score: 0.9142208714315124
#
# Generation 27 - Current best internal CV score: 0.9142208714315124
#
# Generation 28 - Current best internal CV score: 0.9142208714315124
#
# Generation 29 - Current best internal CV score: 0.9142208714315124
#
# Generation 30 - Current best internal CV score: 0.9142208714315124
#
# Generation 31 - Current best internal CV score: 0.9142208714315124
#
# Generation 32 - Current best internal CV score: 0.9142208714315124
#
# Generation 33 - Current best internal CV score: 0.9142208714315124
#
# Generation 34 - Current best internal CV score: 0.9142208714315124
#
# Generation 35 - Current best internal CV score: 0.9142208714315124
#
# Generation 36 - Current best internal CV score: 0.9142208714315124
#
# Generation 37 - Current best internal CV score: 0.9144260018942976
#
# Generation 38 - Current best internal CV score: 0.9144260018942976
#
# Generation 39 - Current best internal CV score: 0.9144260018942976
#
# Generation 40 - Current best internal CV score: 0.9144260018942976
#
# Generation 41 - Current best internal CV score: 0.9144260018942976
#
# Generation 42 - Current best internal CV score: 0.9144260018942976
#
# Generation 43 - Current best internal CV score: 0.9144260018942976
#
# Generation 44 - Current best internal CV score: 0.9144260018942976
#
# Generation 45 - Current best internal CV score: 0.9144260018942976
#
# Generation 46 - Current best internal CV score: 0.9144260018942976
#
# Generation 47 - Current best internal CV score: 0.9146089310076327
#
# Generation 48 - Current best internal CV score: 0.9146089310076327
#
# Generation 49 - Current best internal CV score: 0.9146089310076327
#
# Generation 50 - Current best internal CV score: 0.9146089310076327
#
# Generation 51 - Current best internal CV score: 0.9146089310076327
#
# Generation 52 - Current best internal CV score: 0.9146089310076327
#
# Generation 53 - Current best internal CV score: 0.9146089310076327
#
# Generation 54 - Current best internal CV score: 0.9146089310076327
#
# Generation 55 - Current best internal CV score: 0.9146089310076327
#
# Generation 56 - Current best internal CV score: 0.9146089310076327
#
# Generation 57 - Current best internal CV score: 0.9146089310076327
#
# Generation 58 - Current best internal CV score: 0.9146089310076327
#
# Generation 59 - Current best internal CV score: 0.9146089310076327
#
# Generation 60 - Current best internal CV score: 0.9146089310076327
#
# Generation 61 - Current best internal CV score: 0.9146089310076327
#
# Generation 62 - Current best internal CV score: 0.9146089310076327
#
# Generation 63 - Current best internal CV score: 0.9146089310076327
#
# 78.69 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: GradientBoostingClassifier(RandomForestClassifier(input_matrix, bootstrap=False, criterion=gini, max_features=0.1, min_samples_leaf=11, min_samples_split=3, n_estimators=100), learning_rate=0.01, max_depth=3, max_features=0.8500000000000001, min_samples_leaf=16, min_samples_split=9, n_estimators=100, subsample=0.8)
#
# Weighted F1-score: 0.9380627984645565
#
# End of the TPOT system execution: 2023-01-03 19:19:09.319149

# %%
tpot_X2 = run_tpot(X2_train, y2_train, max_time_mins=60)

# Save the model
tpot_X2.export('tpot_models/tpot_X2.py')

# Save the model as pickle
with open("./tpot_model_X2.pickle", "wb") as f:
    pickle.dump({"template": tpot_X2.fitted_pipeline_, "_imputed": tpot._imputed}, f)
# Out:
# Start TPOT:  2023-01-03 01:55:22.770080 Time Limit per Fold: 120min
# Estimated end: 2023-01-03 09:55:22.770080
#
#
# 120.13 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
# Best pipeline: ExtraTreesClassifier(GradientBoostingClassifier(input_matrix, learning_rate=0.01, max_depth=4, max_features=0.6000000000000001, min_samples_leaf=12, min_samples_split=7, n_estimators=100, subsample=0.6000000000000001), bootstrap=True, criterion=entropy, max_features=0.8, min_samples_leaf=19, min_samples_split=5, n_estimators=100)
#
# 120.28 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
# Best pipeline: GradientBoostingClassifier(SGDClassifier(VarianceThreshold(input_matrix, threshold=0.005), alpha=0.001, eta0=0.01, fit_intercept=False, l1_ratio=0.25, learning_rate=invscaling, loss=squared_hinge, penalty=elasticnet, power_t=0.5), learning_rate=0.1, max_depth=1, max_features=0.9000000000000001, min_samples_leaf=5, min_samples_split=8, n_estimators=100, subsample=0.35000000000000003)
#
# 120.75 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
# Best pipeline: ExtraTreesClassifier(MaxAbsScaler(StandardScaler(ZeroCount(RandomForestClassifier(input_matrix, bootstrap=False, criterion=gini, max_features=0.3, min_samples_leaf=17, min_samples_split=4, n_estimators=100)))), bootstrap=False, criterion=gini, max_features=0.35000000000000003, min_samples_leaf=16, min_samples_split=10, n_estimators=100)
#
# 122.05 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
# Best pipeline: RandomForestClassifier(GradientBoostingClassifier(RandomForestClassifier(input_matrix, bootstrap=True, criterion=gini, max_features=0.7000000000000001, min_samples_leaf=8, min_samples_split=4, n_estimators=100), learning_rate=0.01, max_depth=6, max_features=0.4, min_samples_leaf=6, min_samples_split=14, n_estimators=100, subsample=1.0), bootstrap=False, criterion=gini, max_features=0.8, min_samples_leaf=16, min_samples_split=16, n_estimators=100)
#
# Weighted F1-score: 0.9483206106472407
#
# End of the TPOT system execution: 2023-01-03 09:59:16.803815
